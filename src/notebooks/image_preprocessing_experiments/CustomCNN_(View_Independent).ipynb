# %% [markdown]
# # Custom CNN (View-Independent) Image Preprocessing Pipelines Experiments

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import cv2
import sys
import time
import os

# %%
# Clone the github repository with the source code into this notebook
# !git clone https://github.com/Avneetkaur16/CM3070_Final_Project.git
# %cd CM3070_Final_Project
# Out:
# Cloning into 'CM3070_Final_Project'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 182 (delta 68), reused 148 (delta 55), pack-reused 0 (from 0)
# Receiving objects: 100% (182/182), 1.69 MiB | 25.11 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# /content/CM3070_Final_Project

# %%
# Add path to the source code
sys.path.append('/content/CM3070_Final_Project')

# %%
# Import source code functions from repository code
from src.image_preprocessing.image_preprocessing_pipelines import *
from src.image_preprocessing.image_preprocessors import IMAGE_PREPROCESSORS
from src.utils import *
from src.dataset.view_independent.dataset import generate_dataset
from src.models.view_independent.customCNN import create_custom_cnn_model
from src.models.model_functions import compile_model
from src.visualizations import *

# %%
# Mount the google drive for dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip and extract training, validation and testing datasets (containing images)
# !unzip -q "/content/drive/MyDrive/CBISDDSM/train_dataset.zip" -d "/content/extracted_train_data"
# !unzip -q "/content/drive/MyDrive/CBISDDSM/val_dataset.zip" -d "/content/extracted_val_data"
# !unzip -q "/content/drive/MyDrive/CBISDDSM/test_dataset.zip" -d "/content/extracted_test_data"

# %%
# New dataset root path
dataset_root = "/content/drive/MyDrive/CBISDDSM"

# %%
# Extract training, validation and testing metadata from csv files and store them as dataframes
train_df = pd.read_csv(dataset_root + "/train_data.csv")
val_df = pd.read_csv(dataset_root + "/val_data.csv")
test_df = pd.read_csv(dataset_root + "/test_data.csv")

# %%
# Update 'image_path' of all dataframes with new image path source
train_df['new_image_path'] = train_df['image_path'].apply(update_image_path_training)
val_df['new_image_path'] = val_df['image_path'].apply(update_image_path_validation)
test_df['new_image_path'] = test_df['image_path'].apply(update_image_path_testing)

# %%
# Label encoding all dataframes
train_df['pathology'] = train_df['pathology'].map({'BENIGN': 0.0, 'MALIGNANT': 1.0})
val_df['pathology'] = val_df['pathology'].map({'BENIGN': 0.0, 'MALIGNANT': 1.0})
test_df['pathology'] = test_df['pathology'].map({'BENIGN': 0.0, 'MALIGNANT': 1.0})

# %%
# Print pathology distribution in each set
print(train_df['pathology'].value_counts())
print(val_df['pathology'].value_counts())
print(test_df['pathology'].value_counts())
# Out:
# pathology
# 0.0    1371
# 1.0     904
# Name: count, dtype: int64
# pathology
# 0.0    357
# 1.0    230
# Name: count, dtype: int64
# pathology
# 0.0    382
# 1.0    322
# Name: count, dtype: int64

# %%
# No. of testing image samples
testing_images_count = len(test_df)
# True pathology labels
true_pathology = test_df['pathology']
# Convert true pathology series to numpy array
true_pathology_np = true_pathology.to_numpy()

# %%
# CSV Files to store all experimental results
results_file_path = "/content/drive/MyDrive/CM3070_Final_Project_Experiment_Results/image_preprocessing_results.csv"

# %% [markdown]
# ## P0 Image Preprocessing Pipeline Experiment
#
# **Baseline Image Preprocessing Pipeline**
#
# * Resizing
# * Normalization

# %%
# Select the p0 image preprocessor function from the image preprocessor dictionary
p0 = IMAGE_PREPROCESSORS['P0']

# %%
# Create a tf.data dataset with p0 image preprocessing
train_dataset_p0 = generate_dataset(train_df, 32, p0, 'customCNN', training=True)
val_dataset_p0 = generate_dataset(val_df, 32, p0, 'customCNN', training=False)
test_dataset_p0 = generate_dataset(test_df, 32, p0, 'customCNN', training=False)

# %%
# Create a custom CNN model for p0 pipeline
customCNN_p0 = create_custom_cnn_model()
customCNN_p0 = compile_model(customCNN_p0)

# %%
# Train the model with training dataset for p0 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p0
train_start_p0 = time.time()

# Custom CNN with p0 training for 20 epochs
customCNN_p0.fit(train_dataset_p0, validation_data=val_dataset_p0, epochs=20)

# Memory used in p0
peak_memory_p0 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p0
train_end_p0 = time.time()

# Total training time for p0 in minutes
training_time_p0 = (train_end_p0 - train_start_p0) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 74s 322ms/step - accuracy: 0.5991 - auc: 0.5439 - loss: 0.6922 - precision: 0.4200 - recall: 0.0232 - val_accuracy: 0.6082 - val_auc: 0.5835 - val_loss: 0.6708 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 161ms/step - accuracy: 0.6026 - auc: 0.5940 - loss: 0.6594 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5289 - val_loss: 0.6868 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 169ms/step - accuracy: 0.6026 - auc: 0.4617 - loss: 0.6853 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4954 - val_loss: 0.6828 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 171ms/step - accuracy: 0.6026 - auc: 0.5539 - loss: 0.6652 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6050 - val_loss: 0.6634 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 85s 198ms/step - accuracy: 0.6026 - auc: 0.5719 - loss: 0.6663 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6051 - val_loss: 0.6738 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 166ms/step - accuracy: 0.6009 - auc: 0.5816 - loss: 0.6598 - precision: 0.3000 - recall: 0.0033 - val_accuracy: 0.6082 - val_auc: 0.6317 - val_loss: 0.6435 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - accuracy: 0.6031 - auc: 0.5874 - loss: 0.6912 - precision: 0.5111 - recall: 0.0254 - val_accuracy: 0.6082 - val_auc: 0.6263 - val_loss: 0.6597 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 153ms/step - accuracy: 0.6026 - auc: 0.5481 - loss: 0.6738 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5405 - val_loss: 0.6748 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - accuracy: 0.6026 - auc: 0.5640 - loss: 0.6639 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5973 - val_loss: 0.6576 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 154ms/step - accuracy: 0.6026 - auc: 0.6033 - loss: 0.6541 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6333 - val_loss: 0.6656 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 167ms/step - accuracy: 0.6013 - auc: 0.5971 - loss: 0.6570 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6105 - val_loss: 0.6532 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 168ms/step - accuracy: 0.5991 - auc: 0.5977 - loss: 0.6560 - precision: 0.4000 - recall: 0.0177 - val_accuracy: 0.6150 - val_auc: 0.6080 - val_loss: 0.6485 - val_precision: 0.8333 - val_recall: 0.0217
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 169ms/step - accuracy: 0.6022 - auc: 0.6029 - loss: 0.6560 - precision: 0.4444 - recall: 0.0044 - val_accuracy: 0.6082 - val_auc: 0.6247 - val_loss: 0.6447 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 168ms/step - accuracy: 0.6031 - auc: 0.6121 - loss: 0.6514 - precision: 1.0000 - recall: 0.0011 - val_accuracy: 0.6082 - val_auc: 0.6364 - val_loss: 0.6557 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 197ms/step - accuracy: 0.5996 - auc: 0.5976 - loss: 0.6515 - precision: 0.4255 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6158 - val_loss: 0.6439 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 158ms/step - accuracy: 0.6110 - auc: 0.6221 - loss: 0.6461 - precision: 0.5388 - recall: 0.1460 - val_accuracy: 0.6099 - val_auc: 0.5549 - val_loss: 0.6415 - val_precision: 1.0000 - val_recall: 0.0043
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 159ms/step - accuracy: 0.6119 - auc: 0.6227 - loss: 0.6457 - precision: 0.5255 - recall: 0.2389 - val_accuracy: 0.5673 - val_auc: 0.6284 - val_loss: 0.6390 - val_precision: 0.4630 - val_recall: 0.6522
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 159ms/step - accuracy: 0.6132 - auc: 0.6212 - loss: 0.6388 - precision: 0.5566 - recall: 0.1305 - val_accuracy: 0.6201 - val_auc: 0.6256 - val_loss: 0.6291 - val_precision: 0.5538 - val_recall: 0.1565
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 166ms/step - accuracy: 0.6145 - auc: 0.6287 - loss: 0.6379 - precision: 0.5316 - recall: 0.2511 - val_accuracy: 0.5980 - val_auc: 0.6317 - val_loss: 0.6242 - val_precision: 0.4286 - val_recall: 0.0783
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 168ms/step - accuracy: 0.6167 - auc: 0.6276 - loss: 0.6410 - precision: 0.6176 - recall: 0.0929 - val_accuracy: 0.6048 - val_auc: 0.6295 - val_loss: 0.6211 - val_precision: 0.4800 - val_recall: 0.1043

# %% [markdown]
# ### P0 Image Preprocessing Predictions

# %%
# Predict model's prediction probabilities using test data for p0

# Prediction start time
predict_start_p0 = time.time()

# Custom CNN with p0 predictions
prediction_probs_p0 = customCNN_p0.predict(test_dataset_p0)

# Prediction end time
predict_end_p0 = time.time()

# Total prediction time for p0 in seconds
prediction_time_p0 = predict_end_p0 - predict_start_p0
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step

# %%
# Evaluation metrics for custom CNN with p0
eval_metrics_p0 = customCNN_p0.evaluate(test_dataset_p0, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.5526 - auc: 0.6368 - loss: 0.6536 - precision: 0.5522 - recall: 0.1149

# %%
# Compute predictions using model's prediction probabilities
predictions_p0 = np.where(prediction_probs_p0 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p0 true and predicted values
tn_p0, fp_p0, fn_p0, tp_p0 = confusion_matrix(true_pathology, predictions_p0).ravel()

# Compute specificity using CM
specificity_p0 = tn_p0 / (tn_p0 + fp_p0)

# Compute F1 Score using recall and precision
f1_score_p0 = 0.0
if eval_metrics_p0['precision'] + eval_metrics_p0['recall'] != 0.0:
  f1_score_p0 = (2 * eval_metrics_p0['precision'] * eval_metrics_p0['recall']) / (eval_metrics_p0['precision'] + eval_metrics_p0['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p0 = customCNN_p0.count_params()

# %%
# Generate a results dataframe for results of p0 experiment
results_p0 = generate_results_df('Custom CNN', 'View_Independent', 'P0', eval_metrics_p0, specificity_p0, f1_score_p0, training_time_p0, prediction_time_p0, peak_memory_p0, customCNN_params_p0)

# Store p0 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p0)
# Out:
# Stored results for 0    P0
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P0 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P0 pipeline
plot_training_validation_loss(customCNN_p0.history, 'Custom CNN (View-Independent)', 'P0')

# %%
# Training-Validation Accuracy curve for P0 pipeline
plot_training_validation_accuracy(customCNN_p0.history, 'Custom CNN (View-Independent)', 'P0')

# %%
# Precision-Recall curve for P0 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p0, 'Custom CNN (View-Independent)', 'P0')

# %%
# Confusion matrix for P0 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p0, 'Custom CNN (View-Independent)', 'P0')

# %% [markdown]
# ## P1 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * Normalization

# %%
# Select the p1 image preprocessor function from the image preprocessor dictionary
p1 = IMAGE_PREPROCESSORS['P1']

# %%
# Create a tf.data dataset with p1 image preprocessing
train_dataset_p1 = generate_dataset(train_df, 32, p1, 'customCNN', training=True)
val_dataset_p1 = generate_dataset(val_df, 32, p1, 'customCNN', training=False)
test_dataset_p1 = generate_dataset(test_df, 32, p1, 'customCNN', training=False)

# %%
# Create a custom CNN model for p1 pipeline
customCNN_p1 = create_custom_cnn_model()
customCNN_p1 = compile_model(customCNN_p1)

# %%
# Train the model with training dataset for p1 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p1
train_start_p1 = time.time()

# Custom CNN with p1 training for 20 epochs
customCNN_p1.fit(train_dataset_p1, validation_data=val_dataset_p1, epochs=20)

# Memory used in p1
peak_memory_p1 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p1
train_end_p1 = time.time()

# Total training time for p1 in minutes
training_time_p1 = (train_end_p1 - train_start_p1) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 72s 325ms/step - accuracy: 0.5921 - auc: 0.5023 - loss: 0.7253 - precision: 0.3846 - recall: 0.0442 - val_accuracy: 0.6082 - val_auc: 0.6034 - val_loss: 0.6635 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 159ms/step - accuracy: 0.6022 - auc: 0.5685 - loss: 0.6655 - precision: 0.4000 - recall: 0.0022 - val_accuracy: 0.6082 - val_auc: 0.5817 - val_loss: 0.6639 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 147ms/step - accuracy: 0.6053 - auc: 0.5722 - loss: 0.6656 - precision: 0.5115 - recall: 0.1471 - val_accuracy: 0.6082 - val_auc: 0.6207 - val_loss: 0.6794 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 147ms/step - accuracy: 0.5969 - auc: 0.5939 - loss: 0.6618 - precision: 0.4504 - recall: 0.0653 - val_accuracy: 0.6082 - val_auc: 0.5922 - val_loss: 0.6640 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 148ms/step - accuracy: 0.6127 - auc: 0.5906 - loss: 0.6633 - precision: 0.5714 - recall: 0.1018 - val_accuracy: 0.6116 - val_auc: 0.6221 - val_loss: 0.6474 - val_precision: 0.5060 - val_recall: 0.3696
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 150ms/step - accuracy: 0.6057 - auc: 0.6058 - loss: 0.6537 - precision: 0.5176 - recall: 0.1139 - val_accuracy: 0.6082 - val_auc: 0.6219 - val_loss: 0.6441 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 149ms/step - accuracy: 0.6031 - auc: 0.6012 - loss: 0.6564 - precision: 0.5034 - recall: 0.0830 - val_accuracy: 0.6082 - val_auc: 0.5908 - val_loss: 0.6549 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 150ms/step - accuracy: 0.6013 - auc: 0.6095 - loss: 0.6529 - precision: 0.4933 - recall: 0.1228 - val_accuracy: 0.6099 - val_auc: 0.6287 - val_loss: 0.6468 - val_precision: 0.5041 - val_recall: 0.2652
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 151ms/step - accuracy: 0.6101 - auc: 0.6308 - loss: 0.6452 - precision: 0.5172 - recall: 0.2832 - val_accuracy: 0.6286 - val_auc: 0.6297 - val_loss: 0.6435 - val_precision: 0.6000 - val_recall: 0.1565
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 151ms/step - accuracy: 0.6044 - auc: 0.6266 - loss: 0.6495 - precision: 0.7500 - recall: 0.0066 - val_accuracy: 0.6065 - val_auc: 0.6190 - val_loss: 0.6472 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 151ms/step - accuracy: 0.5960 - auc: 0.5822 - loss: 0.6661 - precision: 0.4725 - recall: 0.1427 - val_accuracy: 0.6082 - val_auc: 0.5965 - val_loss: 0.6562 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 153ms/step - accuracy: 0.6075 - auc: 0.6122 - loss: 0.6511 - precision: 0.5244 - recall: 0.1305 - val_accuracy: 0.6082 - val_auc: 0.5839 - val_loss: 0.6521 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 168ms/step - accuracy: 0.5938 - auc: 0.5461 - loss: 0.6852 - precision: 0.4519 - recall: 0.1040 - val_accuracy: 0.6082 - val_auc: 0.5964 - val_loss: 0.6735 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 166ms/step - accuracy: 0.5903 - auc: 0.5896 - loss: 0.6572 - precision: 0.4352 - recall: 0.1040 - val_accuracy: 0.6082 - val_auc: 0.6037 - val_loss: 0.6413 - val_precision: 0.5000 - val_recall: 0.0130
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 164ms/step - accuracy: 0.6000 - auc: 0.6129 - loss: 0.6456 - precision: 0.4873 - recall: 0.1272 - val_accuracy: 0.6082 - val_auc: 0.6095 - val_loss: 0.6365 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 163ms/step - accuracy: 0.6031 - auc: 0.6098 - loss: 0.6441 - precision: 0.5038 - recall: 0.0730 - val_accuracy: 0.5928 - val_auc: 0.6014 - val_loss: 0.6426 - val_precision: 0.4762 - val_recall: 0.3913
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.6075 - auc: 0.6036 - loss: 0.6439 - precision: 0.5152 - recall: 0.2058 - val_accuracy: 0.6218 - val_auc: 0.6325 - val_loss: 0.6329 - val_precision: 0.7500 - val_recall: 0.0522
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 161ms/step - accuracy: 0.6084 - auc: 0.6314 - loss: 0.6388 - precision: 0.5212 - recall: 0.1770 - val_accuracy: 0.5315 - val_auc: 0.6324 - val_loss: 0.6544 - val_precision: 0.4409 - val_recall: 0.7304
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 163ms/step - accuracy: 0.6022 - auc: 0.6015 - loss: 0.6448 - precision: 0.4966 - recall: 0.0796 - val_accuracy: 0.6235 - val_auc: 0.6182 - val_loss: 0.6395 - val_precision: 0.6047 - val_recall: 0.1130
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 150ms/step - accuracy: 0.6167 - auc: 0.6182 - loss: 0.6393 - precision: 0.5941 - recall: 0.1117 - val_accuracy: 0.6099 - val_auc: 0.6344 - val_loss: 0.6279 - val_precision: 0.5041 - val_recall: 0.2652

# %% [markdown]
# ### P1 Image Preprocessing Predictions

# %%
# Predict model's prediction probabilities using test data for p1

# Prediction start time
predict_start_p1 = time.time()

# Custom CNN with p1 predictions
prediction_probs_p1 = customCNN_p1.predict(test_dataset_p1)

# Prediction end time
predict_end_p1 = time.time()

# Total prediction time for p1 in seconds
prediction_time_p1 = predict_end_p1 - predict_start_p1
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step

# %%
# Evaluation metrics for custom CNN with p1
eval_metrics_p1 = customCNN_p1.evaluate(test_dataset_p1, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.5952 - auc: 0.6341 - loss: 0.6566 - precision: 0.6057 - recall: 0.3292

# %%
# Compute predictions using model's prediction probabilities
predictions_p1 = np.where(prediction_probs_p1 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p1 true and predicted values
tn_p1, fp_p1, fn_p1, tp_p1 = confusion_matrix(true_pathology, predictions_p1).ravel()

# Compute specificity using CM
specificity_p1 = tn_p1 / (tn_p1 + fp_p1)

# Compute F1 Score using recall and precision
f1_score_p1 = 0.0
if eval_metrics_p1['precision'] + eval_metrics_p1['recall'] != 0.0:
  f1_score_p1 = (2 * eval_metrics_p1['precision'] * eval_metrics_p1['recall']) / (eval_metrics_p1['precision'] + eval_metrics_p1['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p1 = customCNN_p1.count_params()

# %%
# Generate a results dataframe for results of p1 experiment
results_p1 = generate_results_df('Custom CNN', 'View_Independent', 'P1', eval_metrics_p1, specificity_p1, f1_score_p1, training_time_p1, prediction_time_p1, peak_memory_p1, customCNN_params_p1)

# Store p1 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p1)
# Out:
# Stored results for 0    P1
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P1 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P1 pipeline
plot_training_validation_loss(customCNN_p1.history, 'Custom CNN (View-Independent)', 'P1')

# %%
# Training-Validation Accuracy curve for P1 pipeline
plot_training_validation_accuracy(customCNN_p1.history, 'Custom CNN (View-Independent)', 'P1')

# %%
# Precision-Recall Curve for P1 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p1, 'Custom CNN (View-Independent)', 'P1')

# %%
# Confusion matrix for P1 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p1, 'Custom CNN (View-Independent)', 'P1')

# %% [markdown]
# ## P2 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * CLAHE
# * Normalization

# %%
# Select the p2 image preprocessor function from the image preprocessor dictionary
p2 = IMAGE_PREPROCESSORS['P2']

# %%
# Create a tf.data dataset with p2 image preprocessing
train_dataset_p2 = generate_dataset(train_df, 32, p2, 'customCNN', training=True)
val_dataset_p2 = generate_dataset(val_df, 32, p2, 'customCNN', training=False)
test_dataset_p2 = generate_dataset(test_df, 32, p2, 'customCNN', training=False)

# %%
# Create a custom CNN model for p2 pipeline
customCNN_p2 = create_custom_cnn_model()
customCNN_p2 = compile_model(customCNN_p2)

# %%
# Train the model with training dataset for p2 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p2
train_start_p2 = time.time()

# Custom CNN with p2 training for 20 epochs
customCNN_p2.fit(train_dataset_p2, validation_data=val_dataset_p2, epochs=20)

# Memory used in p2
peak_memory_p2 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p2
train_end_p2 = time.time()

# Total training time for p2 in minutes
training_time_p2 = (train_end_p2 - train_start_p2) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 320ms/step - accuracy: 0.5956 - auc: 0.4933 - loss: 0.6813 - precision: 0.4200 - recall: 0.0465 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6725 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 48s 162ms/step - accuracy: 0.6026 - auc: 0.5152 - loss: 0.6727 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6699 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 49s 192ms/step - accuracy: 0.6026 - auc: 0.4995 - loss: 0.6740 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5311 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 164ms/step - accuracy: 0.5987 - auc: 0.5011 - loss: 0.6747 - precision: 0.4237 - recall: 0.0277 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6713 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 161ms/step - accuracy: 0.6026 - auc: 0.4777 - loss: 0.6759 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5520 - val_loss: 0.6708 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 157ms/step - accuracy: 0.6026 - auc: 0.4896 - loss: 0.6740 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 156ms/step - accuracy: 0.6026 - auc: 0.4646 - loss: 0.6773 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - accuracy: 0.6026 - auc: 0.4825 - loss: 0.6755 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6717 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 158ms/step - accuracy: 0.6026 - auc: 0.5053 - loss: 0.6734 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6708 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 157ms/step - accuracy: 0.6026 - auc: 0.4827 - loss: 0.6755 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 156ms/step - accuracy: 0.6026 - auc: 0.4938 - loss: 0.6737 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6703 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 157ms/step - accuracy: 0.6026 - auc: 0.4994 - loss: 0.6731 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 154ms/step - accuracy: 0.6026 - auc: 0.5149 - loss: 0.6717 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6699 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 158ms/step - accuracy: 0.6026 - auc: 0.5005 - loss: 0.6741 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 156ms/step - accuracy: 0.6022 - auc: 0.4869 - loss: 0.6773 - precision: 0.4000 - recall: 0.0022 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6702 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 157ms/step - accuracy: 0.6026 - auc: 0.5066 - loss: 0.6740 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 155ms/step - accuracy: 0.6026 - auc: 0.5056 - loss: 0.6728 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 158ms/step - accuracy: 0.6026 - auc: 0.4969 - loss: 0.6737 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 155ms/step - accuracy: 0.6026 - auc: 0.4848 - loss: 0.6741 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 156ms/step - accuracy: 0.6026 - auc: 0.4973 - loss: 0.6729 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P2 Image Preprocessing Predictions

# %%
# Predict model's prediction probabilities using test data for p2

# Prediction start time
predict_start_p2 = time.time()

# Custom CNN with p2 predictions
prediction_probs_p2 = customCNN_p2.predict(test_dataset_p2)

# Prediction end time
predict_end_p2 = time.time()

# Total prediction time for p2 in seconds
prediction_time_p2 = predict_end_p2 - predict_start_p2
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step

# %%
# Evaluation metrics for custom CNN with p2
eval_metrics_p2 = customCNN_p2.evaluate(test_dataset_p2, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.5426 - auc: 0.5000 - loss: 0.6935 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p2 = np.where(prediction_probs_p2 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p2 true and predicted values
tn_p2, fp_p2, fn_p2, tp_p2 = confusion_matrix(true_pathology, predictions_p2).ravel()

# Compute specificity using CM
specificity_p2 = tn_p2 / (tn_p2 + fp_p2)

# Compute F1 Score using recall and precision
f1_score_p2 = 0.0
if eval_metrics_p2['precision'] + eval_metrics_p2['recall'] != 0.0:
  f1_score_p2 = (2 * eval_metrics_p2['precision'] * eval_metrics_p2['recall']) / (eval_metrics_p2['precision'] + eval_metrics_p2['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p2 = customCNN_p2.count_params()

# %%
# Generate a results dataframe for results of p2 experiment
results_p2 = generate_results_df('Custom CNN', 'View_Independent', 'P2', eval_metrics_p2, specificity_p2, f1_score_p2, training_time_p2, prediction_time_p2, peak_memory_p2, customCNN_params_p2)

# Store p2 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p2)
# Out:
# Stored results for 0    P2
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P2 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P2 pipeline
plot_training_validation_loss(customCNN_p2.history, 'Custom CNN (View-Independent)', 'P2')

# %%
# Training-Validation Accuracy curve for P2 pipeline
plot_training_validation_accuracy(customCNN_p2.history, 'Custom CNN (View-Independent)', 'P2')

# %%
# Precision-Recall Curve for P2 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p2, 'Custom CNN (View-Independent)', 'P2')

# %%
# Confusion matrix for P2 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p2, 'Custom CNN (View-Independent)', 'P2')

# %% [markdown]
# ## P3 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Gamma Correction
# * Normalization

# %%
# Select the p3 image preprocessor function from the image preprocessor dictionary
p3 = IMAGE_PREPROCESSORS['P3']

# %%
# Create a tf.data dataset with p3 image preprocessing
train_dataset_p3 = generate_dataset(train_df, 32, p3, 'customCNN', training=True)
val_dataset_p3 = generate_dataset(val_df, 32, p3, 'customCNN', training=False)
test_dataset_p3 = generate_dataset(test_df, 32, p3, 'customCNN', training=False)

# %%
# Create a custom CNN model for p3 pipeline
customCNN_p3 = create_custom_cnn_model()
customCNN_p3 = compile_model(customCNN_p3)

# %%
# Train the model with training dataset for p3 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p3
train_start_p3 = time.time()

# Custom CNN with p3 training for 20 epochs
customCNN_p3.fit(train_dataset_p3, validation_data=val_dataset_p3, epochs=20)

# Memory used in p3
peak_memory_p3 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p3
train_end_p3 = time.time()

# Total training time for p3 in minutes
training_time_p3 = (train_end_p3 - train_start_p3) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 75s 336ms/step - accuracy: 0.5982 - auc: 0.4935 - loss: 0.6870 - precision: 0.4643 - recall: 0.0719 - val_accuracy: 0.6082 - val_auc: 0.5836 - val_loss: 0.6720 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 168ms/step - accuracy: 0.6026 - auc: 0.5375 - loss: 0.6699 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5760 - val_loss: 0.6633 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 166ms/step - accuracy: 0.6026 - auc: 0.5232 - loss: 0.6726 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6182 - val_loss: 0.6667 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.6026 - auc: 0.5262 - loss: 0.6734 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5895 - val_loss: 0.6593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 159ms/step - accuracy: 0.6026 - auc: 0.4910 - loss: 0.6812 - precision: 0.5000 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.5068 - val_loss: 0.6852 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - accuracy: 0.6026 - auc: 0.4998 - loss: 0.6777 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5179 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 160ms/step - accuracy: 0.6026 - auc: 0.5247 - loss: 0.6710 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6194 - val_loss: 0.6815 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 163ms/step - accuracy: 0.5947 - auc: 0.5356 - loss: 0.6757 - precision: 0.4357 - recall: 0.0675 - val_accuracy: 0.6133 - val_auc: 0.6329 - val_loss: 0.6532 - val_precision: 0.5789 - val_recall: 0.0478
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 164ms/step - accuracy: 0.5982 - auc: 0.5590 - loss: 0.6711 - precision: 0.4286 - recall: 0.0332 - val_accuracy: 0.6082 - val_auc: 0.6179 - val_loss: 0.6647 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 163ms/step - accuracy: 0.6026 - auc: 0.5891 - loss: 0.6601 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6183 - val_loss: 0.6482 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 161ms/step - accuracy: 0.5987 - auc: 0.6072 - loss: 0.6566 - precision: 0.4759 - recall: 0.0985 - val_accuracy: 0.6082 - val_auc: 0.6223 - val_loss: 0.6467 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 155ms/step - accuracy: 0.5974 - auc: 0.5947 - loss: 0.6607 - precision: 0.3696 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5778 - val_loss: 0.6582 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 163ms/step - accuracy: 0.5996 - auc: 0.5794 - loss: 0.6641 - precision: 0.4771 - recall: 0.0808 - val_accuracy: 0.5741 - val_auc: 0.6501 - val_loss: 0.6750 - val_precision: 0.4747 - val_recall: 0.8174
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 159ms/step - accuracy: 0.5960 - auc: 0.5357 - loss: 0.6751 - precision: 0.4211 - recall: 0.0442 - val_accuracy: 0.6082 - val_auc: 0.4571 - val_loss: 0.6720 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 154ms/step - accuracy: 0.6018 - auc: 0.5186 - loss: 0.6720 - precision: 0.4857 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.5073 - val_loss: 0.6787 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.6026 - auc: 0.4577 - loss: 0.6793 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4305 - val_loss: 0.6760 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 163ms/step - accuracy: 0.6026 - auc: 0.5028 - loss: 0.6750 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5212 - val_loss: 0.6758 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 163ms/step - accuracy: 0.6026 - auc: 0.5544 - loss: 0.6675 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5951 - val_loss: 0.6562 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 161ms/step - accuracy: 0.6026 - auc: 0.5744 - loss: 0.6638 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5656 - val_loss: 0.6659 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 157ms/step - accuracy: 0.6031 - auc: 0.5886 - loss: 0.6574 - precision: 0.6000 - recall: 0.0033 - val_accuracy: 0.6082 - val_auc: 0.6365 - val_loss: 0.6447 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
# Predict model's prediction probabilities using test data for p3

# Prediction start time
predict_start_p3 = time.time()

# Custom CNN with p3 predictions
prediction_probs_p3 = customCNN_p3.predict(test_dataset_p3)

# Prediction end time
predict_end_p3 = time.time()

# Total prediction time for p3 in seconds
prediction_time_p3 = predict_end_p3 - predict_start_p3
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step

# %%
# Evaluation metrics for custom CNN with p3
eval_metrics_p3 = customCNN_p3.evaluate(test_dataset_p3, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.5426 - auc: 0.6413 - loss: 0.6719 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p3 = np.where(prediction_probs_p3 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p3 true and predicted values
tn_p3, fp_p3, fn_p3, tp_p3 = confusion_matrix(true_pathology, predictions_p3).ravel()

# Compute specificity using CM
specificity_p3 = tn_p3 / (tn_p3 + fp_p3)

# Compute F1 Score using recall and precision
f1_score_p3 = 0.0
if eval_metrics_p3['precision'] + eval_metrics_p3['recall'] != 0.0:
  f1_score_p3 = (2 * eval_metrics_p3['precision'] * eval_metrics_p3['recall']) / (eval_metrics_p3['precision'] + eval_metrics_p3['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p3 = customCNN_p3.count_params()

# %%
# Generate a results dataframe for results of p3 experiment
results_p3 = generate_results_df('Custom CNN', 'View_Independent', 'P3', eval_metrics_p3, specificity_p3, f1_score_p3, training_time_p3, prediction_time_p3, peak_memory_p3, customCNN_params_p3)

# Store p3 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p3)
# Out:
# Stored results for 0    P3
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P3 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P3 pipeline
plot_training_validation_loss(customCNN_p3.history, 'Custom CNN (View-Independent)', 'P3')

# %%
# Training-Validation Accuracy curve for P3 pipeline
plot_training_validation_accuracy(customCNN_p3.history, 'Custom CNN (View-Independent)', 'P3')

# %%
# Precision-Recall Curve for P3 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p3, 'Custom CNN (View-Independent)', 'P3')

# %%
# Confusion matrix for P3 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p3, 'Custom CNN (View-Independent)', 'P3')

# %% [markdown]
# ## P4 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Median Blur
# * Normalization

# %%
# Select the p4 image preprocessor function from the image preprocessor dictionary
p4 = IMAGE_PREPROCESSORS['P4']

# %%
# Create a tf.data dataset with p4 image preprocessing
train_dataset_p4 = generate_dataset(train_df, 32, p4, 'customCNN', training=True)
val_dataset_p4 = generate_dataset(val_df, 32, p4, 'customCNN', training=False)
test_dataset_p4 = generate_dataset(test_df, 32, p4, 'customCNN', training=False)

# %%
# Create a custom CNN model for p4 pipeline
customCNN_p4 = create_custom_cnn_model()
customCNN_p4 = compile_model(customCNN_p4)

# %%
# Train the model with training dataset for p4 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p4
train_start_p4 = time.time()

# Custom CNN with p4 training for 20 epochs
customCNN_p4.fit(train_dataset_p4, validation_data=val_dataset_p4, epochs=20)

# Memory used in p4
peak_memory_p4 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p4
train_end_p4 = time.time()

# Total training time for p4 in minutes
training_time_p4 = (train_end_p4 - train_start_p4) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 75s 315ms/step - accuracy: 0.5943 - auc: 0.4803 - loss: 0.7073 - precision: 0.3733 - recall: 0.0310 - val_accuracy: 0.6082 - val_auc: 0.6091 - val_loss: 0.6594 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 148ms/step - accuracy: 0.6053 - auc: 0.5520 - loss: 0.6670 - precision: 0.6250 - recall: 0.0166 - val_accuracy: 0.6082 - val_auc: 0.6026 - val_loss: 0.6647 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 149ms/step - accuracy: 0.6013 - auc: 0.5846 - loss: 0.6605 - precision: 0.2857 - recall: 0.0022 - val_accuracy: 0.6082 - val_auc: 0.5903 - val_loss: 0.6592 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 157ms/step - accuracy: 0.6022 - auc: 0.6078 - loss: 0.6561 - precision: 0.4706 - recall: 0.0088 - val_accuracy: 0.6099 - val_auc: 0.6226 - val_loss: 0.6555 - val_precision: 1.0000 - val_recall: 0.0043
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 146ms/step - accuracy: 0.6044 - auc: 0.5942 - loss: 0.6620 - precision: 0.5238 - recall: 0.0487 - val_accuracy: 0.6218 - val_auc: 0.6192 - val_loss: 0.6461 - val_precision: 0.5571 - val_recall: 0.1696
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 154ms/step - accuracy: 0.6136 - auc: 0.6107 - loss: 0.6548 - precision: 0.5385 - recall: 0.1936 - val_accuracy: 0.6065 - val_auc: 0.6116 - val_loss: 0.6449 - val_precision: 0.4615 - val_recall: 0.0261
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 160ms/step - accuracy: 0.6088 - auc: 0.6186 - loss: 0.6518 - precision: 0.5190 - recall: 0.2113 - val_accuracy: 0.5877 - val_auc: 0.6382 - val_loss: 0.6665 - val_precision: 0.4754 - val_recall: 0.5043
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 146ms/step - accuracy: 0.6000 - auc: 0.5809 - loss: 0.6641 - precision: 0.4873 - recall: 0.1272 - val_accuracy: 0.6099 - val_auc: 0.6255 - val_loss: 0.6413 - val_precision: 0.5556 - val_recall: 0.0217
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 41s 140ms/step - accuracy: 0.6009 - auc: 0.6131 - loss: 0.6536 - precision: 0.4902 - recall: 0.1106 - val_accuracy: 0.6048 - val_auc: 0.6115 - val_loss: 0.6463 - val_precision: 0.2500 - val_recall: 0.0043
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 41s 142ms/step - accuracy: 0.6070 - auc: 0.5881 - loss: 0.6667 - precision: 0.5240 - recall: 0.1206 - val_accuracy: 0.6099 - val_auc: 0.6266 - val_loss: 0.6521 - val_precision: 0.6000 - val_recall: 0.0130
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 41s 141ms/step - accuracy: 0.6092 - auc: 0.6290 - loss: 0.6465 - precision: 0.5231 - recall: 0.1881 - val_accuracy: 0.6218 - val_auc: 0.6232 - val_loss: 0.6475 - val_precision: 0.5294 - val_recall: 0.3130
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 183ms/step - accuracy: 0.6088 - auc: 0.6212 - loss: 0.6480 - precision: 0.5389 - recall: 0.1073 - val_accuracy: 0.6269 - val_auc: 0.6204 - val_loss: 0.6433 - val_precision: 0.6000 - val_recall: 0.1435
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 155ms/step - accuracy: 0.6132 - auc: 0.6173 - loss: 0.6500 - precision: 0.5351 - recall: 0.2024 - val_accuracy: 0.6371 - val_auc: 0.6286 - val_loss: 0.6401 - val_precision: 0.6393 - val_recall: 0.1696
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 40s 138ms/step - accuracy: 0.6202 - auc: 0.6296 - loss: 0.6464 - precision: 0.5546 - recall: 0.2246 - val_accuracy: 0.6201 - val_auc: 0.6207 - val_loss: 0.6450 - val_precision: 0.5412 - val_recall: 0.2000
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 41s 138ms/step - accuracy: 0.6189 - auc: 0.6331 - loss: 0.6416 - precision: 0.5580 - recall: 0.1969 - val_accuracy: 0.6082 - val_auc: 0.6432 - val_loss: 0.6803 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 41s 140ms/step - accuracy: 0.6171 - auc: 0.6026 - loss: 0.6560 - precision: 0.5490 - recall: 0.2046 - val_accuracy: 0.6082 - val_auc: 0.6301 - val_loss: 0.6538 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.6044 - auc: 0.6198 - loss: 0.6476 - precision: 0.5667 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.6248 - val_loss: 0.6465 - val_precision: 0.5000 - val_recall: 0.0130
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 153ms/step - accuracy: 0.6079 - auc: 0.6147 - loss: 0.6511 - precision: 0.5448 - recall: 0.0808 - val_accuracy: 0.5997 - val_auc: 0.6083 - val_loss: 0.6457 - val_precision: 0.4576 - val_recall: 0.1174
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - accuracy: 0.6101 - auc: 0.6214 - loss: 0.6471 - precision: 0.5220 - recall: 0.2235 - val_accuracy: 0.6065 - val_auc: 0.6248 - val_loss: 0.6433 - val_precision: 0.4815 - val_recall: 0.0565
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 139ms/step - accuracy: 0.6299 - auc: 0.6377 - loss: 0.6425 - precision: 0.5917 - recall: 0.2212 - val_accuracy: 0.6286 - val_auc: 0.6251 - val_loss: 0.6399 - val_precision: 0.5909 - val_recall: 0.1696

# %%
# Predict model's prediction probabilities using test data for p4

# Prediction start time
predict_start_p4 = time.time()

# Custom CNN with p4 predictions
prediction_probs_p4 = customCNN_p4.predict(test_dataset_p4)

# Prediction end time
predict_end_p4 = time.time()

# Total prediction time for p4 in seconds
prediction_time_p4 = predict_end_p4 - predict_start_p4
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step

# %%
# Evaluation metrics for custom CNN with p4
eval_metrics_p4 = customCNN_p4.evaluate(test_dataset_p4, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.5611 - auc: 0.6392 - loss: 0.6602 - precision: 0.5684 - recall: 0.1677

# %%
# Compute predictions using model's prediction probabilities
predictions_p4 = np.where(prediction_probs_p4 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p4 true and predicted values
tn_p4, fp_p4, fn_p4, tp_p4 = confusion_matrix(true_pathology, predictions_p4).ravel()

# Compute specificity using CM
specificity_p4 = tn_p4 / (tn_p4 + fp_p4)

# Compute F1 Score using recall and precision
f1_score_p4 = 0.0
if eval_metrics_p4['precision'] + eval_metrics_p4['recall'] != 0.0:
  f1_score_p4 = (2 * eval_metrics_p4['precision'] * eval_metrics_p4['recall']) / (eval_metrics_p4['precision'] + eval_metrics_p4['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p4 = customCNN_p4.count_params()

# %%
# Generate a results dataframe for results of p4 experiment
results_p4 = generate_results_df('Custom CNN', 'View_Independent', 'P4', eval_metrics_p4, specificity_p4, f1_score_p4, training_time_p4, prediction_time_p4, peak_memory_p4, customCNN_params_p4)

# Store p4 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p4)
# Out:
# Stored results for 0    P4
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P4 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P4 pipeline
plot_training_validation_loss(customCNN_p4.history, 'Custom CNN (View-Independent)', 'P4')

# %%
# Training-Validation Accuracy curve for P4 pipeline
plot_training_validation_accuracy(customCNN_p4.history, 'Custom CNN (View-Independent)', 'P4')

# %%
# Precision-Recall Curve for P4 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p4, 'Custom CNN (View-Independent)', 'P4')

# %%
# Confusion matrix for P4 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p4, 'Custom CNN (View-Independent)', 'P4')

# %% [markdown]
# ## P5 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * Gamma Correction
# * Normalization

# %%
# Select the p5 image preprocessor function from the image preprocessor dictionary
p5 = IMAGE_PREPROCESSORS['P5']

# %%
# Create a tf.data dataset with p5 image preprocessing
train_dataset_p5 = generate_dataset(train_df, 32, p5, 'customCNN', training=True)
val_dataset_p5 = generate_dataset(val_df, 32, p5, 'customCNN', training=False)
test_dataset_p5 = generate_dataset(test_df, 32, p5, 'customCNN', training=False)

# %%
# Create a custom CNN model for p5 pipeline
customCNN_p5 = create_custom_cnn_model()
customCNN_p5 = compile_model(customCNN_p5)

# %%
# Train the model with training dataset for p5 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p5
train_start_p5 = time.time()

# Custom CNN with p5 training for 20 epochs
customCNN_p5.fit(train_dataset_p5, validation_data=val_dataset_p5, epochs=20)

# Memory used in p5
peak_memory_p5 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p5
train_end_p5 = time.time()

# Total training time for p5 in minutes
training_time_p5 = (train_end_p5 - train_start_p5) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 353ms/step - accuracy: 0.6013 - auc: 0.4939 - loss: 0.6922 - precision: 0.4819 - recall: 0.0442 - val_accuracy: 0.6082 - val_auc: 0.5995 - val_loss: 0.6709 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 48s 177ms/step - accuracy: 0.5974 - auc: 0.5147 - loss: 0.6753 - precision: 0.4423 - recall: 0.0509 - val_accuracy: 0.6082 - val_auc: 0.5848 - val_loss: 0.6680 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - accuracy: 0.6026 - auc: 0.5078 - loss: 0.6743 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6290 - val_loss: 0.6637 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 164ms/step - accuracy: 0.5938 - auc: 0.5306 - loss: 0.6753 - precision: 0.4359 - recall: 0.0752 - val_accuracy: 0.6082 - val_auc: 0.5232 - val_loss: 0.6764 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 165ms/step - accuracy: 0.6022 - auc: 0.5189 - loss: 0.6762 - precision: 0.4286 - recall: 0.0033 - val_accuracy: 0.6082 - val_auc: 0.6052 - val_loss: 0.6735 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 166ms/step - accuracy: 0.6026 - auc: 0.5212 - loss: 0.6757 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6123 - val_loss: 0.6672 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - accuracy: 0.6026 - auc: 0.5623 - loss: 0.6668 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5710 - val_loss: 0.6636 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 163ms/step - accuracy: 0.6022 - auc: 0.5704 - loss: 0.6639 - precision: 0.4915 - recall: 0.0321 - val_accuracy: 0.6082 - val_auc: 0.6076 - val_loss: 0.6525 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 163ms/step - accuracy: 0.6026 - auc: 0.5961 - loss: 0.6579 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6209 - val_loss: 0.6476 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 51s 198ms/step - accuracy: 0.5996 - auc: 0.5804 - loss: 0.6646 - precision: 0.4533 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.6369 - val_loss: 0.6455 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 169ms/step - accuracy: 0.5996 - auc: 0.5872 - loss: 0.6599 - precision: 0.4831 - recall: 0.1106 - val_accuracy: 0.6099 - val_auc: 0.6095 - val_loss: 0.6538 - val_precision: 0.5077 - val_recall: 0.1435
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - accuracy: 0.6000 - auc: 0.5864 - loss: 0.6607 - precision: 0.4400 - recall: 0.0243 - val_accuracy: 0.6082 - val_auc: 0.6058 - val_loss: 0.6492 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 164ms/step - accuracy: 0.6026 - auc: 0.6079 - loss: 0.6558 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6232 - val_loss: 0.6474 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - accuracy: 0.6031 - auc: 0.5943 - loss: 0.6581 - precision: 0.5098 - recall: 0.0288 - val_accuracy: 0.6082 - val_auc: 0.6296 - val_loss: 0.6425 - val_precision: 0.5000 - val_recall: 0.0043
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - accuracy: 0.6035 - auc: 0.6015 - loss: 0.6551 - precision: 1.0000 - recall: 0.0022 - val_accuracy: 0.6099 - val_auc: 0.6086 - val_loss: 0.6504 - val_precision: 1.0000 - val_recall: 0.0043
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 161ms/step - accuracy: 0.6057 - auc: 0.6098 - loss: 0.6539 - precision: 0.6522 - recall: 0.0166 - val_accuracy: 0.6099 - val_auc: 0.6340 - val_loss: 0.6423 - val_precision: 0.6667 - val_recall: 0.0087
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 49s 175ms/step - accuracy: 0.5996 - auc: 0.6247 - loss: 0.6488 - precision: 0.4807 - recall: 0.0962 - val_accuracy: 0.6082 - val_auc: 0.6335 - val_loss: 0.6513 - val_precision: 0.5000 - val_recall: 0.0087
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 48s 179ms/step - accuracy: 0.6101 - auc: 0.6229 - loss: 0.6509 - precision: 0.6735 - recall: 0.0365 - val_accuracy: 0.6116 - val_auc: 0.6355 - val_loss: 0.6393 - val_precision: 0.6000 - val_recall: 0.0261
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 166ms/step - accuracy: 0.6105 - auc: 0.6059 - loss: 0.6558 - precision: 0.5577 - recall: 0.0962 - val_accuracy: 0.6252 - val_auc: 0.6375 - val_loss: 0.6474 - val_precision: 0.6471 - val_recall: 0.0957
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - accuracy: 0.6114 - auc: 0.6147 - loss: 0.6519 - precision: 0.5323 - recall: 0.1825 - val_accuracy: 0.5945 - val_auc: 0.5847 - val_loss: 0.6744 - val_precision: 0.4394 - val_recall: 0.1261

# %%
# Predict model's prediction probabilities using test data for p5

# Prediction start time
predict_start_p5 = time.time()

# Custom CNN with p5 predictions
prediction_probs_p5 = customCNN_p5.predict(test_dataset_p5)

# Prediction end time
predict_end_p5 = time.time()

# Total prediction time for p5 in seconds
prediction_time_p5 = predict_end_p5 - predict_start_p5
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step

# %%
# Evaluation metrics for custom CNN with p5
eval_metrics_p5 = customCNN_p5.evaluate(test_dataset_p5, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.5369 - auc: 0.5520 - loss: 0.6848 - precision: 0.4722 - recall: 0.1056

# %%
# Compute predictions using model's prediction probabilities
predictions_p5 = np.where(prediction_probs_p5 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p5 true and predicted values
tn_p5, fp_p5, fn_p5, tp_p5 = confusion_matrix(true_pathology, predictions_p5).ravel()

# Compute specificity using CM
specificity_p5 = tn_p5 / (tn_p5 + fp_p5)

# Compute F1 Score using recall and precision
f1_score_p5 = 0.0
if eval_metrics_p5['precision'] + eval_metrics_p5['recall'] != 0.0:
  f1_score_p5 = (2 * eval_metrics_p5['precision'] * eval_metrics_p5['recall']) / (eval_metrics_p5['precision'] + eval_metrics_p5['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p5 = customCNN_p5.count_params()

# %%
# Generate a results dataframe for results of p5 experiment
results_p5 = generate_results_df('Custom CNN', 'View_Independent', 'P5', eval_metrics_p5, specificity_p5, f1_score_p5, training_time_p5, prediction_time_p5, peak_memory_p5, customCNN_params_p5)

# Store p5 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p5)
# Out:
# Stored results for 0    P5
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P5 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P5 pipeline
plot_training_validation_loss(customCNN_p5.history, 'Custom CNN (View-Independent)', 'P5')

# %%
# Training-Validation Accuracy curve for P5 pipeline
plot_training_validation_accuracy(customCNN_p5.history, 'Custom CNN (View-Independent)', 'P5')

# %%
# Precision-Recall Curve for P5 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p5, 'Custom CNN (View-Independent)', 'P5')

# %%
# Confusion matrix for P5 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p5, 'Custom CNN (View-Independent)', 'P5')

# %% [markdown]
# ## P6 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * Median Blur
# * Normalization

# %%
# Select the p6 image preprocessor function from the image preprocessor dictionary
p6 = IMAGE_PREPROCESSORS['P6']

# %%
# Create a tf.data dataset with p6 image preprocessing
train_dataset_p6 = generate_dataset(train_df, 32, p6, 'customCNN', training=True)
val_dataset_p6 = generate_dataset(val_df, 32, p6, 'customCNN', training=False)
test_dataset_p6 = generate_dataset(test_df, 32, p6, 'customCNN', training=False)

# %%
# Create a custom CNN model for p6 pipeline
customCNN_p6 = create_custom_cnn_model()
customCNN_p6 = compile_model(customCNN_p6)

# %%
# Train the model with training dataset for p6 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p6
train_start_p6 = time.time()

# Custom CNN with p6 training for 20 epochs
customCNN_p6.fit(train_dataset_p6, validation_data=val_dataset_p6, epochs=20)

# Memory used in p6
peak_memory_p6 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p6
train_end_p6 = time.time()

# Total training time for p6 in minutes
training_time_p6 = (train_end_p6 - train_start_p6) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 76s 324ms/step - accuracy: 0.5969 - auc: 0.5332 - loss: 0.6940 - precision: 0.4570 - recall: 0.0763 - val_accuracy: 0.6082 - val_auc: 0.6265 - val_loss: 0.6613 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.6022 - auc: 0.5677 - loss: 0.6651 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6011 - val_loss: 0.6504 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 146ms/step - accuracy: 0.5974 - auc: 0.5954 - loss: 0.6567 - precision: 0.4630 - recall: 0.0830 - val_accuracy: 0.6082 - val_auc: 0.6363 - val_loss: 0.6848 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 148ms/step - accuracy: 0.5996 - auc: 0.5895 - loss: 0.6602 - precision: 0.4646 - recall: 0.0509 - val_accuracy: 0.6235 - val_auc: 0.6030 - val_loss: 0.6527 - val_precision: 0.5556 - val_recall: 0.1957
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 147ms/step - accuracy: 0.6048 - auc: 0.6015 - loss: 0.6532 - precision: 0.5106 - recall: 0.1327 - val_accuracy: 0.5690 - val_auc: 0.6130 - val_loss: 0.6496 - val_precision: 0.4553 - val_recall: 0.5087
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 147ms/step - accuracy: 0.6035 - auc: 0.6130 - loss: 0.6459 - precision: 0.5033 - recall: 0.1704 - val_accuracy: 0.6133 - val_auc: 0.6274 - val_loss: 0.6419 - val_precision: 0.5211 - val_recall: 0.1609
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 149ms/step - accuracy: 0.6044 - auc: 0.6051 - loss: 0.6578 - precision: 0.5060 - recall: 0.1858 - val_accuracy: 0.6082 - val_auc: 0.5184 - val_loss: 0.6679 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 148ms/step - accuracy: 0.6075 - auc: 0.5912 - loss: 0.6634 - precision: 0.5224 - recall: 0.1416 - val_accuracy: 0.6082 - val_auc: 0.5966 - val_loss: 0.6445 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 153ms/step - accuracy: 0.5987 - auc: 0.6084 - loss: 0.6484 - precision: 0.4818 - recall: 0.1316 - val_accuracy: 0.5843 - val_auc: 0.6226 - val_loss: 0.6246 - val_precision: 0.4314 - val_recall: 0.1913
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 164ms/step - accuracy: 0.6075 - auc: 0.6155 - loss: 0.6315 - precision: 0.5124 - recall: 0.2511 - val_accuracy: 0.6048 - val_auc: 0.6238 - val_loss: 0.6210 - val_precision: 0.4167 - val_recall: 0.0217
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 162ms/step - accuracy: 0.6149 - auc: 0.6459 - loss: 0.6234 - precision: 0.5383 - recall: 0.2179 - val_accuracy: 0.6065 - val_auc: 0.6261 - val_loss: 0.6228 - val_precision: 0.4894 - val_recall: 0.1000
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 165ms/step - accuracy: 0.6127 - auc: 0.6349 - loss: 0.6257 - precision: 0.5352 - recall: 0.1936 - val_accuracy: 0.6099 - val_auc: 0.6456 - val_loss: 0.6137 - val_precision: 0.5075 - val_recall: 0.1478
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 161ms/step - accuracy: 0.6233 - auc: 0.6563 - loss: 0.6188 - precision: 0.5485 - recall: 0.2942 - val_accuracy: 0.6014 - val_auc: 0.6400 - val_loss: 0.6388 - val_precision: 0.4737 - val_recall: 0.1565
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 159ms/step - accuracy: 0.6105 - auc: 0.6617 - loss: 0.6185 - precision: 0.5237 - recall: 0.2201 - val_accuracy: 0.5843 - val_auc: 0.6310 - val_loss: 0.6257 - val_precision: 0.4300 - val_recall: 0.1870
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 150ms/step - accuracy: 0.6145 - auc: 0.6459 - loss: 0.6239 - precision: 0.5405 - recall: 0.1991 - val_accuracy: 0.5963 - val_auc: 0.6154 - val_loss: 0.6272 - val_precision: 0.4462 - val_recall: 0.1261
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 148ms/step - accuracy: 0.6215 - auc: 0.6522 - loss: 0.6128 - precision: 0.6019 - recall: 0.1405 - val_accuracy: 0.6014 - val_auc: 0.6388 - val_loss: 0.6158 - val_precision: 0.4744 - val_recall: 0.1609
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 145ms/step - accuracy: 0.6154 - auc: 0.6567 - loss: 0.6127 - precision: 0.5299 - recall: 0.2843 - val_accuracy: 0.5911 - val_auc: 0.6252 - val_loss: 0.6403 - val_precision: 0.4468 - val_recall: 0.1826
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.6356 - auc: 0.6781 - loss: 0.6021 - precision: 0.5858 - recall: 0.2832 - val_accuracy: 0.5928 - val_auc: 0.6302 - val_loss: 0.6553 - val_precision: 0.4430 - val_recall: 0.1522
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 42s 150ms/step - accuracy: 0.6396 - auc: 0.6854 - loss: 0.6008 - precision: 0.5847 - recall: 0.3208 - val_accuracy: 0.6099 - val_auc: 0.6325 - val_loss: 0.6344 - val_precision: 0.5122 - val_recall: 0.0913
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - accuracy: 0.6382 - auc: 0.6821 - loss: 0.6059 - precision: 0.6047 - recall: 0.2588 - val_accuracy: 0.6099 - val_auc: 0.6370 - val_loss: 0.6293 - val_precision: 0.5041 - val_recall: 0.2696

# %%
# Predict model's prediction probabilities using test data for p6

# Prediction start time
predict_start_p6 = time.time()

# Custom CNN with p6 predictions
prediction_probs_p6 = customCNN_p6.predict(test_dataset_p6)

# Prediction end time
predict_end_p6 = time.time()

# Total prediction time for p6 in seconds
prediction_time_p6 = predict_end_p6 - predict_start_p6
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step

# %%
# Evaluation metrics for custom CNN with p6
eval_metrics_p6 = customCNN_p6.evaluate(test_dataset_p6, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.5852 - auc: 0.6427 - loss: 0.6729 - precision: 0.5904 - recall: 0.3043

# %%
# Compute predictions using model's prediction probabilities
predictions_p6 = np.where(prediction_probs_p6 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p6 true and predicted values
tn_p6, fp_p6, fn_p6, tp_p6 = confusion_matrix(true_pathology, predictions_p6).ravel()

# Compute specificity using CM
specificity_p6 = tn_p6 / (tn_p6 + fp_p6)

# Compute F1 Score using recall and precision
f1_score_p6 = 0.0
if eval_metrics_p6['precision'] + eval_metrics_p6['recall'] != 0.0:
  f1_score_p6 = (2 * eval_metrics_p6['precision'] * eval_metrics_p6['recall']) / (eval_metrics_p6['precision'] + eval_metrics_p6['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p6 = customCNN_p6.count_params()

# %%
# Generate a results dataframe for results of p6 experiment
results_p6 = generate_results_df('Custom CNN', 'View_Independent', 'P6', eval_metrics_p6, specificity_p6, f1_score_p6, training_time_p6, prediction_time_p6, peak_memory_p6, customCNN_params_p6)

# Store p6 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p6)
# Out:
# Stored results for 0    P6
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P6 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P6 pipeline
plot_training_validation_loss(customCNN_p6.history, 'Custom CNN (View-Independent)', 'P6')

# %%
# Training-Validation Accuracy curve for P6 pipeline
plot_training_validation_accuracy(customCNN_p6.history, 'Custom CNN (View-Independent)', 'P6')

# %%
# Precision-Recall Curve for P6 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p6, 'Custom CNN (View-Independent)', 'P6')

# %%
# Confusion matrix for P6 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p6, 'Custom CNN (View-Independent)', 'P6')

# %% [markdown]
# ## P7 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * CLAHE
# * Gamma Correction
# * Normalization

# %%
# Select the p7 image preprocessor function from the image preprocessor dictionary
p7 = IMAGE_PREPROCESSORS['P7']

# %%
# Create a tf.data dataset with p7 image preprocessing
train_dataset_p7 = generate_dataset(train_df, 32, p7, 'customCNN', training=True)
val_dataset_p7 = generate_dataset(val_df, 32, p7, 'customCNN', training=False)
test_dataset_p7 = generate_dataset(test_df, 32, p7, 'customCNN', training=False)

# %%
# Create a custom CNN model for p7 pipeline
customCNN_p7 = create_custom_cnn_model()
customCNN_p7 = compile_model(customCNN_p7)

# %%
# Train the model with training dataset for p7 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p7
train_start_p7 = time.time()

# Custom CNN with p7 training for 20 epochs
customCNN_p7.fit(train_dataset_p7, validation_data=val_dataset_p7, epochs=20)

# Memory used in p7
peak_memory_p7 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p7
train_end_p7 = time.time()

# Total training time for p7 in minutes
training_time_p7 = (train_end_p7 - train_start_p7) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 89s 394ms/step - accuracy: 0.6000 - auc: 0.4772 - loss: 0.7062 - precision: 0.4375 - recall: 0.0232 - val_accuracy: 0.6082 - val_auc: 0.5648 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 49s 205ms/step - accuracy: 0.5916 - auc: 0.5164 - loss: 0.6786 - precision: 0.3529 - recall: 0.0332 - val_accuracy: 0.6082 - val_auc: 0.5423 - val_loss: 0.6811 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 184ms/step - accuracy: 0.6026 - auc: 0.5138 - loss: 0.6753 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6725 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 172ms/step - accuracy: 0.6026 - auc: 0.4916 - loss: 0.6757 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5369 - val_loss: 0.6708 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 179ms/step - accuracy: 0.6026 - auc: 0.5024 - loss: 0.6733 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 171ms/step - accuracy: 0.6026 - auc: 0.4957 - loss: 0.6734 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6712 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 182ms/step - accuracy: 0.6026 - auc: 0.5076 - loss: 0.6731 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 48s 190ms/step - accuracy: 0.6026 - auc: 0.5024 - loss: 0.6733 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5541 - val_loss: 0.6719 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 183ms/step - accuracy: 0.6026 - auc: 0.4866 - loss: 0.6751 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6706 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 172ms/step - accuracy: 0.6026 - auc: 0.4812 - loss: 0.6743 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5466 - val_loss: 0.6688 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 178ms/step - accuracy: 0.6026 - auc: 0.5008 - loss: 0.6729 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4932 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 172ms/step - accuracy: 0.6026 - auc: 0.5034 - loss: 0.6724 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5728 - val_loss: 0.6684 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 176ms/step - accuracy: 0.6026 - auc: 0.5051 - loss: 0.6733 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5601 - val_loss: 0.6688 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 49s 193ms/step - accuracy: 0.6026 - auc: 0.4960 - loss: 0.6748 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6722 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 184ms/step - accuracy: 0.6026 - auc: 0.5006 - loss: 0.6730 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6022 - val_loss: 0.6677 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 173ms/step - accuracy: 0.5987 - auc: 0.5419 - loss: 0.6712 - precision: 0.4384 - recall: 0.0354 - val_accuracy: 0.6082 - val_auc: 0.5750 - val_loss: 0.6691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 176ms/step - accuracy: 0.6013 - auc: 0.4975 - loss: 0.6769 - precision: 0.2000 - recall: 0.0011 - val_accuracy: 0.6082 - val_auc: 0.4953 - val_loss: 0.6738 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 170ms/step - accuracy: 0.6026 - auc: 0.4900 - loss: 0.6746 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4949 - val_loss: 0.6703 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 170ms/step - accuracy: 0.6026 - auc: 0.4962 - loss: 0.6741 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4969 - val_loss: 0.6725 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 48s 184ms/step - accuracy: 0.6026 - auc: 0.4972 - loss: 0.6738 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4910 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
# Predict model's prediction probabilities using test data for p7

# Prediction start time
predict_start_p7 = time.time()

# Custom CNN with p7 predictions
prediction_probs_p7 = customCNN_p7.predict(test_dataset_p7)

# Prediction end time
predict_end_p7 = time.time()

# Total prediction time for p7 in seconds
prediction_time_p7 = predict_end_p7 - predict_start_p7
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step

# %%
# Evaluation metrics for custom CNN with p7
eval_metrics_p7 = customCNN_p7.evaluate(test_dataset_p7, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.5426 - auc: 0.4909 - loss: 0.6996 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p7 = np.where(prediction_probs_p7 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p7 true and predicted values
tn_p7, fp_p7, fn_p7, tp_p7 = confusion_matrix(true_pathology, predictions_p7).ravel()

# Compute specificity using CM
specificity_p7 = tn_p7 / (tn_p7 + fp_p7)

# Compute F1 Score using recall and precision
f1_score_p7 = 0.0
if eval_metrics_p7['precision'] + eval_metrics_p7['recall'] != 0.0:
  f1_score_p7 = (2 * eval_metrics_p7['precision'] * eval_metrics_p7['recall']) / (eval_metrics_p7['precision'] + eval_metrics_p7['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p7 = customCNN_p7.count_params()

# %%
# Generate a results dataframe for results of p7 experiment
results_p7 = generate_results_df('Custom CNN', 'View_Independent', 'P7', eval_metrics_p7, specificity_p7, f1_score_p7, training_time_p7, prediction_time_p7, peak_memory_p7, customCNN_params_p7)

# Store p7 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p7)
# Out:
# Stored results for 0    P7
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P7 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P7 pipeline
plot_training_validation_loss(customCNN_p7.history, 'Custom CNN (View-Independent)', 'P7')

# %%
# Training-Validation Accuracy curve for P7 pipeline
plot_training_validation_accuracy(customCNN_p7.history, 'Custom CNN (View-Independent)', 'P7')

# %%
# Precision-Recall Curve for P7 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p7, 'Custom CNN (View-Independent)', 'P7')

# %%
# Confusion matrix for P7 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p7, 'Custom CNN (View-Independent)', 'P7')

# %% [markdown]
# ## P8 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * CLAHE
# * Median Blur
# * Normalization

# %%
# Select the p8 image preprocessor function from the image preprocessor dictionary
p8 = IMAGE_PREPROCESSORS['P8']

# %%
# Create a tf.data dataset with p8 image preprocessing
train_dataset_p8 = generate_dataset(train_df, 32, p8, 'customCNN', training=True)
val_dataset_p8 = generate_dataset(val_df, 32, p8, 'customCNN', training=False)
test_dataset_p8 = generate_dataset(test_df, 32, p8, 'customCNN', training=False)

# %%
# Create a custom CNN model for p8 pipeline
customCNN_p8 = create_custom_cnn_model()
customCNN_p8 = compile_model(customCNN_p8)

# %%
# Train the model with training dataset for p8 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p8
train_start_p8 = time.time()

# Custom CNN with p8 training for 20 epochs
customCNN_p8.fit(train_dataset_p8, validation_data=val_dataset_p8, epochs=20)

# Memory used in p8
peak_memory_p8 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p8
train_end_p8 = time.time()

# Total training time for p8 in minutes
training_time_p8 = (train_end_p8 - train_start_p8) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 78s 334ms/step - accuracy: 0.5903 - auc: 0.5196 - loss: 0.6825 - precision: 0.3571 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.4197 - val_loss: 0.6786 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 149ms/step - accuracy: 0.5969 - auc: 0.5145 - loss: 0.6782 - precision: 0.4414 - recall: 0.0542 - val_accuracy: 0.6082 - val_auc: 0.5867 - val_loss: 0.6748 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 79s 148ms/step - accuracy: 0.6026 - auc: 0.5163 - loss: 0.6786 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5015 - val_loss: 0.6732 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 147ms/step - accuracy: 0.6026 - auc: 0.5149 - loss: 0.6740 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6225 - val_loss: 0.6753 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 147ms/step - accuracy: 0.6009 - auc: 0.5656 - loss: 0.6650 - precision: 0.4545 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.5165 - val_loss: 0.6662 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 147ms/step - accuracy: 0.6026 - auc: 0.5657 - loss: 0.6659 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6139 - val_loss: 0.6472 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 145ms/step - accuracy: 0.6009 - auc: 0.5861 - loss: 0.6611 - precision: 0.3889 - recall: 0.0077 - val_accuracy: 0.5622 - val_auc: 0.6227 - val_loss: 0.6551 - val_precision: 0.4569 - val_recall: 0.6217
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 144ms/step - accuracy: 0.6004 - auc: 0.5086 - loss: 0.6801 - precision: 0.4667 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.4988 - val_loss: 0.6745 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 146ms/step - accuracy: 0.6022 - auc: 0.5340 - loss: 0.6790 - precision: 0.4878 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.5370 - val_loss: 0.6671 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 149ms/step - accuracy: 0.6009 - auc: 0.6003 - loss: 0.6555 - precision: 0.4167 - recall: 0.0111 - val_accuracy: 0.6082 - val_auc: 0.5812 - val_loss: 0.6569 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 146ms/step - accuracy: 0.6062 - auc: 0.5985 - loss: 0.6578 - precision: 0.6429 - recall: 0.0199 - val_accuracy: 0.6116 - val_auc: 0.6080 - val_loss: 0.6481 - val_precision: 1.0000 - val_recall: 0.0087
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 147ms/step - accuracy: 0.6105 - auc: 0.6221 - loss: 0.6449 - precision: 0.5506 - recall: 0.1084 - val_accuracy: 0.5451 - val_auc: 0.6057 - val_loss: 0.6628 - val_precision: 0.4490 - val_recall: 0.7087
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.6088 - auc: 0.6207 - loss: 0.6455 - precision: 0.5158 - recall: 0.2533 - val_accuracy: 0.6031 - val_auc: 0.6423 - val_loss: 0.6186 - val_precision: 0.4819 - val_recall: 0.1739
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.6167 - auc: 0.6381 - loss: 0.6297 - precision: 0.5435 - recall: 0.2212 - val_accuracy: 0.5894 - val_auc: 0.6227 - val_loss: 0.6209 - val_precision: 0.4382 - val_recall: 0.1696
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 147ms/step - accuracy: 0.6255 - auc: 0.6540 - loss: 0.6209 - precision: 0.5602 - recall: 0.2677 - val_accuracy: 0.5809 - val_auc: 0.6106 - val_loss: 0.6258 - val_precision: 0.4385 - val_recall: 0.2478
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 148ms/step - accuracy: 0.6532 - auc: 0.6779 - loss: 0.6122 - precision: 0.6032 - recall: 0.3717 - val_accuracy: 0.5809 - val_auc: 0.6188 - val_loss: 0.6238 - val_precision: 0.4574 - val_recall: 0.3739
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 150ms/step - accuracy: 0.6479 - auc: 0.6936 - loss: 0.6017 - precision: 0.5860 - recall: 0.3883 - val_accuracy: 0.5877 - val_auc: 0.6109 - val_loss: 0.6263 - val_precision: 0.4610 - val_recall: 0.3087
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 148ms/step - accuracy: 0.6426 - auc: 0.6926 - loss: 0.6044 - precision: 0.5860 - recall: 0.3429 - val_accuracy: 0.5860 - val_auc: 0.6173 - val_loss: 0.6644 - val_precision: 0.4645 - val_recall: 0.3696
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 147ms/step - accuracy: 0.6607 - auc: 0.7068 - loss: 0.6035 - precision: 0.6006 - recall: 0.4358 - val_accuracy: 0.5894 - val_auc: 0.6193 - val_loss: 0.6270 - val_precision: 0.4621 - val_recall: 0.2913
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 146ms/step - accuracy: 0.6668 - auc: 0.7296 - loss: 0.5798 - precision: 0.6099 - recall: 0.4480 - val_accuracy: 0.5894 - val_auc: 0.6154 - val_loss: 0.6421 - val_precision: 0.4610 - val_recall: 0.2826

# %%
# Predict model's prediction probabilities using test data for p8

# Prediction start time
predict_start_p8 = time.time()

# Custom CNN with p8 predictions
prediction_probs_p8 = customCNN_p8.predict(test_dataset_p8)

# Prediction end time
predict_end_p8 = time.time()

# Total prediction time for p8 in seconds
prediction_time_p8 = predict_end_p8 - predict_start_p8
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step

# %%
# Evaluation metrics for custom CNN with p8
eval_metrics_p8 = customCNN_p8.evaluate(test_dataset_p8, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.5909 - auc: 0.6253 - loss: 0.6826 - precision: 0.5977 - recall: 0.3230

# %%
# Compute predictions using model's prediction probabilities
predictions_p8 = np.where(prediction_probs_p8 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p8 true and predicted values
tn_p8, fp_p8, fn_p8, tp_p8 = confusion_matrix(true_pathology, predictions_p8).ravel()

# Compute specificity using CM
specificity_p8 = tn_p8 / (tn_p8 + fp_p8)

# Compute F1 Score using recall and precision
f1_score_p8 = 0.0
if eval_metrics_p8['precision'] + eval_metrics_p8['recall'] != 0.0:
  f1_score_p8 = (2 * eval_metrics_p8['precision'] * eval_metrics_p8['recall']) / (eval_metrics_p8['precision'] + eval_metrics_p8['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p8 = customCNN_p8.count_params()

# %%
# Generate a results dataframe for results of p8 experiment
results_p8 = generate_results_df('Custom CNN', 'View_Independent', 'P8', eval_metrics_p8, specificity_p8, f1_score_p8, training_time_p8, prediction_time_p8, peak_memory_p8, customCNN_params_p8)

# Store p8 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p8)
# Out:
# Stored results for 0    P8
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P8 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P8 pipeline
plot_training_validation_loss(customCNN_p8.history, 'Custom CNN (View-Independent)', 'P8')

# %%
# Training-Validation Accuracy curve for P8 pipeline
plot_training_validation_accuracy(customCNN_p8.history, 'Custom CNN (View-Independent)', 'P8')

# %%
# Precision-Recall Curve for P8 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p8, 'Custom CNN (View-Independent)', 'P8')

# %%
# Confusion matrix for P8 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p8, 'Custom CNN (View-Independent)', 'P8')

# %% [markdown]
# ## P9 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Gamma Correction
# * Median Blur
# * Normalization

# %%
# Select the p9 image preprocessor function from the image preprocessor dictionary
p9 = IMAGE_PREPROCESSORS['P9']

# %%
# Create a tf.data dataset with p9 image preprocessing
train_dataset_p9 = generate_dataset(train_df, 32, p9, 'customCNN', training=True)
val_dataset_p9 = generate_dataset(val_df, 32, p9, 'customCNN', training=False)
test_dataset_p9 = generate_dataset(test_df, 32, p9, 'customCNN', training=False)

# %%
# Create a custom CNN model for p9 pipeline
customCNN_p9 = create_custom_cnn_model()
customCNN_p9 = compile_model(customCNN_p9)

# %%
# Train the model with training dataset for p9 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p9
train_start_p9 = time.time()

# Custom CNN with p9 training for 20 epochs
customCNN_p9.fit(train_dataset_p9, validation_data=val_dataset_p9, epochs=20)

# Memory used in p9
peak_memory_p9 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p9
train_end_p9 = time.time()

# Total training time for p9 in minutes
training_time_p9 = (train_end_p9 - train_start_p9) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 76s 370ms/step - accuracy: 0.5890 - auc: 0.4999 - loss: 0.6897 - precision: 0.3434 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.5832 - val_loss: 0.6815 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 158ms/step - accuracy: 0.6026 - auc: 0.4701 - loss: 0.6845 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6051 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 159ms/step - accuracy: 0.6026 - auc: 0.5409 - loss: 0.6706 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6176 - val_loss: 0.7707 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 159ms/step - accuracy: 0.6031 - auc: 0.5050 - loss: 0.6823 - precision: 0.6667 - recall: 0.0022 - val_accuracy: 0.6082 - val_auc: 0.5310 - val_loss: 0.6706 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 160ms/step - accuracy: 0.6026 - auc: 0.4981 - loss: 0.6740 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.6169 - val_loss: 0.6689 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 157ms/step - accuracy: 0.6026 - auc: 0.4991 - loss: 0.6770 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4997 - val_loss: 0.6744 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 158ms/step - accuracy: 0.6026 - auc: 0.5254 - loss: 0.6717 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4885 - val_loss: 0.6733 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 157ms/step - accuracy: 0.6026 - auc: 0.4905 - loss: 0.6728 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5068 - val_loss: 0.6702 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 157ms/step - accuracy: 0.6026 - auc: 0.4988 - loss: 0.6719 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4996 - val_loss: 0.6702 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 158ms/step - accuracy: 0.5982 - auc: 0.5041 - loss: 0.7769 - precision: 0.3684 - recall: 0.0155 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6715 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 158ms/step - accuracy: 0.6026 - auc: 0.4873 - loss: 0.6730 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - accuracy: 0.6026 - auc: 0.4978 - loss: 0.6724 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6699 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 157ms/step - accuracy: 0.6026 - auc: 0.4799 - loss: 0.6728 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 158ms/step - accuracy: 0.6026 - auc: 0.4885 - loss: 0.6727 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 161ms/step - accuracy: 0.6026 - auc: 0.4827 - loss: 0.6727 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 165ms/step - accuracy: 0.6026 - auc: 0.5142 - loss: 0.6717 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 159ms/step - accuracy: 0.6026 - auc: 0.5095 - loss: 0.6717 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 43s 162ms/step - accuracy: 0.6026 - auc: 0.5068 - loss: 0.6720 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 164ms/step - accuracy: 0.6026 - auc: 0.4870 - loss: 0.6726 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 165ms/step - accuracy: 0.6026 - auc: 0.4809 - loss: 0.6729 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
# Predict model's prediction probabilities using test data for p9

# Prediction start time
predict_start_p9 = time.time()

# Custom CNN with p9 predictions
prediction_probs_p9 = customCNN_p9.predict(test_dataset_p9)

# Prediction end time
predict_end_p9 = time.time()

# Total prediction time for p9 in seconds
prediction_time_p9 = predict_end_p9 - predict_start_p9
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step

# %%
# Evaluation metrics for custom CNN with p9
eval_metrics_p9 = customCNN_p9.evaluate(test_dataset_p9, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.5426 - auc: 0.5000 - loss: 0.6966 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p9 = np.where(prediction_probs_p9 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p9 true and predicted values
tn_p9, fp_p9, fn_p9, tp_p9 = confusion_matrix(true_pathology, predictions_p9).ravel()

# Compute specificity using CM
specificity_p9 = tn_p9 / (tn_p9 + fp_p9)

# Compute F1 Score using recall and precision
f1_score_p9 = 0.0
if eval_metrics_p9['precision'] + eval_metrics_p9['recall'] != 0.0:
  f1_score_p9 = (2 * eval_metrics_p9['precision'] * eval_metrics_p9['recall']) / (eval_metrics_p9['precision'] + eval_metrics_p9['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p9 = customCNN_p9.count_params()

# %%
# Generate a results dataframe for results of p9 experiment
results_p9 = generate_results_df('Custom CNN', 'View_Independent', 'P9', eval_metrics_p9, specificity_p9, f1_score_p9, training_time_p9, prediction_time_p9, peak_memory_p9, customCNN_params_p9)

# Store p9 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p9)
# Out:
# Stored results for 0    P9
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P9 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P9 pipeline
plot_training_validation_loss(customCNN_p9.history, 'Custom CNN (View-Independent)', 'P9')

# %%
# Training-Validation Accuracy curve for P9 pipeline
plot_training_validation_accuracy(customCNN_p9.history, 'Custom CNN (View-Independent)', 'P9')

# %%
# Precision-Recall Curve for P9 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p9, 'Custom CNN (View-Independent)', 'P9')

# %%
# Confusion matrix for P9 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p9, 'Custom CNN (View-Independent)', 'P9')

# %% [markdown]
# ## P10 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * CLAHE
# * Gamma Correction
# * Median Blur
# * Normalization

# %%
# Select the p10 image preprocessor function from the image preprocessor dictionary
p10 = IMAGE_PREPROCESSORS['P10']

# %%
# Create a tf.data dataset with p10 image preprocessing
train_dataset_p10 = generate_dataset(train_df, 32, p10, 'customCNN', training=True)
val_dataset_p10 = generate_dataset(val_df, 32, p10, 'customCNN', training=False)
test_dataset_p10 = generate_dataset(test_df, 32, p10, 'customCNN', training=False)

# %%
# Create a custom CNN model for p10 pipeline
customCNN_p10 = create_custom_cnn_model()
customCNN_p10 = compile_model(customCNN_p10)

# %%
# Train the model with training dataset for p10 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p10
train_start_p10 = time.time()

# Custom CNN with p10 training for 20 epochs
customCNN_p10.fit(train_dataset_p10, validation_data=val_dataset_p10, epochs=20)

# Memory used in p10
peak_memory_p10 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p10
train_end_p10 = time.time()

# Total training time for p10 in minutes
training_time_p10 = (train_end_p10 - train_start_p10) / 60.0
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 80s 378ms/step - accuracy: 0.6009 - auc: 0.5006 - loss: 0.7200 - precision: 0.4778 - recall: 0.0476 - val_accuracy: 0.6082 - val_auc: 0.4364 - val_loss: 0.6716 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 165ms/step - accuracy: 0.6035 - auc: 0.4857 - loss: 0.6771 - precision: 0.6667 - recall: 0.0044 - val_accuracy: 0.6082 - val_auc: 0.5473 - val_loss: 0.6712 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 169ms/step - accuracy: 0.6031 - auc: 0.4929 - loss: 0.6771 - precision: 0.6667 - recall: 0.0022 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6765 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 47s 174ms/step - accuracy: 0.6026 - auc: 0.5027 - loss: 0.6773 - precision: 0.5000 - recall: 0.0011 - val_accuracy: 0.6082 - val_auc: 0.5268 - val_loss: 0.6808 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 48s 181ms/step - accuracy: 0.6026 - auc: 0.5069 - loss: 0.6740 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.4296 - val_loss: 0.6733 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 164ms/step - accuracy: 0.6026 - auc: 0.5229 - loss: 0.6722 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5533 - val_loss: 0.6695 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 167ms/step - accuracy: 0.6026 - auc: 0.5021 - loss: 0.6738 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5937 - val_loss: 0.6685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 164ms/step - accuracy: 0.6026 - auc: 0.5000 - loss: 0.6752 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5884 - val_loss: 0.6742 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 165ms/step - accuracy: 0.6018 - auc: 0.4965 - loss: 0.6772 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6735 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 162ms/step - accuracy: 0.6026 - auc: 0.4956 - loss: 0.6759 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6717 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 167ms/step - accuracy: 0.6026 - auc: 0.4831 - loss: 0.6744 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 49s 194ms/step - accuracy: 0.6026 - auc: 0.4743 - loss: 0.6756 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6733 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 46s 170ms/step - accuracy: 0.6026 - auc: 0.5072 - loss: 0.6729 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 160ms/step - accuracy: 0.6026 - auc: 0.5000 - loss: 0.6728 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 165ms/step - accuracy: 0.6026 - auc: 0.4923 - loss: 0.6736 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6699 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 159ms/step - accuracy: 0.6026 - auc: 0.4667 - loss: 0.6754 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 164ms/step - accuracy: 0.6026 - auc: 0.4906 - loss: 0.6732 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 158ms/step - accuracy: 0.6026 - auc: 0.4757 - loss: 0.6741 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 44s 161ms/step - accuracy: 0.6026 - auc: 0.4996 - loss: 0.6727 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 45s 160ms/step - accuracy: 0.6026 - auc: 0.4989 - loss: 0.6728 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6082 - val_auc: 0.5000 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
# Predict model's prediction probabilities using test data for p10

# Prediction start time
predict_start_p10 = time.time()

# Custom CNN with p10 predictions
prediction_probs_p10 = customCNN_p10.predict(test_dataset_p10)

# Prediction end time
predict_end_p10 = time.time()

# Total prediction time for p10 in seconds
prediction_time_p10 = predict_end_p10 - predict_start_p10
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step

# %%
# Evaluation metrics for custom CNN with p10
eval_metrics_p10 = customCNN_p10.evaluate(test_dataset_p10, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.5426 - auc: 0.5000 - loss: 0.6957 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p10 = np.where(prediction_probs_p10 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p10 true and predicted values
tn_p10, fp_p10, fn_p10, tp_p10 = confusion_matrix(true_pathology, predictions_p10).ravel()

# Compute specificity using CM
specificity_p10 = tn_p10 / (tn_p10 + fp_p10)

# Compute F1 Score using recall and precision
f1_score_p10 = 0.0
if eval_metrics_p10['precision'] + eval_metrics_p10['recall'] != 0.0:
  f1_score_p10 = (2 * eval_metrics_p10['precision'] * eval_metrics_p10['recall']) / (eval_metrics_p10['precision'] + eval_metrics_p10['recall'])

# Parameters of custom CNN View-Independent model
customCNN_params_p10 = customCNN_p10.count_params()

# %%
# Generate a results dataframe for results of p10 experiment
results_p10 = generate_results_df('Custom CNN', 'View_Independent', 'P10', eval_metrics_p10, specificity_p10, f1_score_p10, training_time_p10, prediction_time_p10, peak_memory_p10, customCNN_params_p10)

# Store p10 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p10)
# Out:
# Stored results for 0    P10
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P10 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P10 pipeline
plot_training_validation_loss(customCNN_p10.history, 'Custom CNN (View-Independent)', 'P10')

# %%
# Training-Validation Accuracy curve for P10 pipeline
plot_training_validation_accuracy(customCNN_p10.history, 'Custom CNN (View-Independent)', 'P10')

# %%
# Precision-Recall Curve for P10 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p10, 'Custom CNN (View-Independent)', 'P10')

# %%
# Confusion matrix for P10 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p10, 'Custom CNN (View-Independent)', 'P10')
