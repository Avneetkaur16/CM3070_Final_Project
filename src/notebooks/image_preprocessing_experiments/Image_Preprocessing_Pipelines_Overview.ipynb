# %% [markdown]
# # Image Preprocessing Pipelines Overview

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import sys

# %%
# Clone the github repository with source code
# !git clone https://github.com/Avneetkaur16/CM3070_Final_Project.git
# %cd CM3070_Final_Project
# Out:
# Cloning into 'CM3070_Final_Project'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 120 (delta 48), reused 101 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 499.67 KiB | 16.66 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/CM3070_Final_Project

# %%
# Add path to the repository code in this notebook
sys.path.append('/content/CM3070_Final_Project')

# %%
# Import image preprocessing pipeline functions from source code repository
from src.image_preprocessing.image_preprocessing_pipelines import *

# %%
# Load the sample image path
sample_image_path = "/content/sample.jpg"

# %% [markdown]
# ### Original Image Sample

# %%
sample_image = plt.imread(sample_image_path)
plt.imshow(sample_image)

# %% [markdown]
# ### P0: Baseline Preprocessing (Resizing + Normalization)

# %%
p0_image = baseline_preprocessing(sample_image_path)
plt.imshow(p0_image)

# %% [markdown]
# ### P1: Grayscale Preprocessing (Resizing + Grayscale + Normalization)

# %%
p1_image = grayscale_preprocessing(sample_image_path)
plt.imshow(p1_image)

# %% [markdown]
# ### P2: CLAHE Preprocessing (Resizing + CLAHE + Normalization)

# %%
p2_image = clahe_preprocessing(sample_image_path)
plt.imshow(p2_image)

# %% [markdown]
# ### P3: Gamma Correction Preprocessing (Resizing + Gamma Correction + Normalization)

# %%
p3_image = gamma_correction_preprocessing(sample_image_path)
plt.imshow(p3_image)

# %% [markdown]
# ### P4: Median Blur Preprocessing (Resizing + Median Blur + Normalization)

# %%
p4_image = median_blur_preprocessing(sample_image_path)
plt.imshow(p4_image)

# %% [markdown]
# ### P5: Graycale and Gamma Correction Preprocessing (Resizing + Grayscale + Gamma Correction + Normalization)

# %%
p5_image = grayscale_gamma_correction_preprocessing(sample_image_path)
plt.imshow(p5_image)

# %% [markdown]
# ### P6: Grayscale and Median Blur Preprocessing (Resizing + Grayscale + Median Blur + Normalization)

# %%
p6_image = grayscale_median_blur_preprocessing(sample_image_path)
plt.imshow(p6_image)

# %% [markdown]
# ### P7: CLAHE and Gamma Correction Preprocessing (Resizing + CLAHE + Gamma Correction + Normalization)

# %%
p7_image = clahe_gamma_correction_preprocessing(sample_image_path)
plt.imshow(p7_image)

# %% [markdown]
# ### P8: CLAHE and Median Blur Preprocessing (Resizing + CLAHE + Median Blur + Normalization)

# %%
p8_image = clahe_median_blur_preprocessing(sample_image_path)
plt.imshow(p8_image)

# %% [markdown]
# ### P9: Gamma Correction and Median Blur Preprocessing (Resizing + Gamma Correction + Median Blur + Normalization)

# %%
p9_image = gamma_correction_median_blur_preprocessing(sample_image_path)
plt.imshow(p9_image)

# %% [markdown]
# ### P10: Grayscale, CLAHE, Gamma Correction and Median Blur Preprocessing (Resizing + Grayscale + CLAHE + Gamma Correction + Median Blur + Normalization)

# %%
p10_image = grayscale_clahe_gamma_correction_median_blur_preprocessing(sample_image_path)
plt.imshow(p10_image)
