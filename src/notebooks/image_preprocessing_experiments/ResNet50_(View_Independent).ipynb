# %% [markdown]
# # ResNet50 (View-Independent) Image Preprocessing Pipelines Experiments

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.applications import ResNet50
import cv2
import sys
import time
import os

# %%
# Fixed seed
tf.keras.utils.set_random_seed(123)
tf.config.experimental.enable_op_determinism()

# %%
# Clone the github repository with the source code into this notebook
# !git clone https://github.com/Avneetkaur16/CM3070_Final_Project.git
# %cd CM3070_Final_Project
# Out:
# Cloning into 'CM3070_Final_Project'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 189 (delta 70), reused 154 (delta 57), pack-reused 0 (from 0)
# Receiving objects: 100% (189/189), 3.08 MiB | 1.67 MiB/s, done.
# Resolving deltas: 100% (70/70), done.
# /content/CM3070_Final_Project

# %%
# Add path to the source code
sys.path.append('/content/CM3070_Final_Project')

# %%
# Import source code functions from repository code
from src.image_preprocessing.image_preprocessing_pipelines import *
from src.image_preprocessing.image_preprocessors import IMAGE_PREPROCESSORS
from src.utils import *
from src.dataset.view_independent.dataset import generate_dataset
from src.models.view_independent.resnet50CNN import create_resnet50_model
from src.models.model_functions import compile_model
from src.visualizations import *

# %%
# Mount the google drive for dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip and extract training, validation and testing datasets (containing images)
# !unzip -q "/content/drive/MyDrive/CBISDDSM/train_dataset.zip" -d "/content/extracted_train_data"
# !unzip -q "/content/drive/MyDrive/CBISDDSM/val_dataset.zip" -d "/content/extracted_val_data"
# !unzip -q "/content/drive/MyDrive/CBISDDSM/test_dataset.zip" -d "/content/extracted_test_data"

# %%
# New dataset root path
dataset_root = "/content/drive/MyDrive/CBISDDSM"

# %%
# Extract training, validation and testing metadata from csv files and store them as dataframes
train_df = pd.read_csv(dataset_root + "/train_data.csv")
val_df = pd.read_csv(dataset_root + "/val_data.csv")
test_df = pd.read_csv(dataset_root + "/test_data.csv")

# %%
# Update 'image_path' of all dataframes with new image path source
train_df['new_image_path'] = train_df['image_path'].apply(update_image_path_training)
val_df['new_image_path'] = val_df['image_path'].apply(update_image_path_validation)
test_df['new_image_path'] = test_df['image_path'].apply(update_image_path_testing)

# %%
# Label encoding all dataframes
train_df['pathology'] = train_df['pathology'].map({'BENIGN': 0.0, 'MALIGNANT': 1.0})
val_df['pathology'] = val_df['pathology'].map({'BENIGN': 0.0, 'MALIGNANT': 1.0})
test_df['pathology'] = test_df['pathology'].map({'BENIGN': 0.0, 'MALIGNANT': 1.0})

# %%
# Print pathology distribution in each set
print(train_df['pathology'].value_counts())
print(val_df['pathology'].value_counts())
print(test_df['pathology'].value_counts())
# Out:
# pathology
# 0.0    1371
# 1.0     904
# Name: count, dtype: int64
# pathology
# 0.0    357
# 1.0    230
# Name: count, dtype: int64
# pathology
# 0.0    382
# 1.0    322
# Name: count, dtype: int64

# %%
# No. of testing image samples
testing_images_count = len(test_df)

# True pathology labels
true_pathology = test_df['pathology']

# Convert true pathology series to numpy array
true_pathology_np = true_pathology.to_numpy()

# %%
# CSV Files to store all experimental results
results_file_path = "/content/drive/MyDrive/CM3070_Final_Project_Experiment_Results/image_preprocessing_results.csv"

# %% [markdown]
# ## P0 Image Preprocessing Pipeline Experiment
#
# **Baseline Image Preprocessing Pipeline**
#
# * Resizing
# * Normalization

# %%
# Select the p0 image preprocessor function from the image preprocessor dictionary
p0 = IMAGE_PREPROCESSORS['P0']

# %%
# Create a tf.data dataset with p0 image preprocessing
train_dataset_p0 = generate_dataset(train_df, 32, p0, 'resnet50', training=True)
val_dataset_p0 = generate_dataset(val_df, 32, p0, 'resnet50', training=False)
test_dataset_p0 = generate_dataset(test_df, 32, p0, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p0 pipeline
resnet50_p0 = create_resnet50_model()
resnet50_p0 = compile_model(resnet50_p0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Train Resnet50 with training dataset for p0 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p0
train_start_p0 = time.time()

# Resnet50 with p0 training for 20 epochs
resnet50_p0.fit(train_dataset_p0, validation_data=val_dataset_p0, epochs=20)

# Memory used in p0
peak_memory_p0 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p0
train_end_p0 = time.time()

# Total training time for p0 in minutes
training_time_p0 = (train_end_p0 - train_start_p0)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 70s 237ms/step - accuracy: 0.5464 - auc: 0.5008 - loss: 0.7252 - precision: 0.3897 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5334 - val_loss: 0.6729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 56s 201ms/step - accuracy: 0.5719 - auc: 0.4935 - loss: 0.6913 - precision: 0.3871 - recall: 0.1327 - val_accuracy: 0.6082 - val_auc: 0.5023 - val_loss: 0.6693 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 203ms/step - accuracy: 0.5846 - auc: 0.4947 - loss: 0.6839 - precision: 0.3787 - recall: 0.0708 - val_accuracy: 0.6082 - val_auc: 0.4960 - val_loss: 0.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 208ms/step - accuracy: 0.5864 - auc: 0.5039 - loss: 0.6797 - precision: 0.4206 - recall: 0.1084 - val_accuracy: 0.6082 - val_auc: 0.5159 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 206ms/step - accuracy: 0.6009 - auc: 0.4918 - loss: 0.6786 - precision: 0.4524 - recall: 0.0210 - val_accuracy: 0.6082 - val_auc: 0.6192 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 207ms/step - accuracy: 0.5978 - auc: 0.5128 - loss: 0.6769 - precision: 0.4321 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.5632 - val_loss: 0.6718 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 56s 204ms/step - accuracy: 0.5890 - auc: 0.4948 - loss: 0.6791 - precision: 0.2615 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5978 - val_loss: 0.6720 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 56s 205ms/step - accuracy: 0.6000 - auc: 0.4907 - loss: 0.6765 - precision: 0.3500 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5864 - val_loss: 0.6682 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 204ms/step - accuracy: 0.5987 - auc: 0.4993 - loss: 0.6764 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6164 - val_loss: 0.6716 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 211ms/step - accuracy: 0.6009 - auc: 0.5089 - loss: 0.6755 - precision: 0.4730 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.6164 - val_loss: 0.6684 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 56s 217ms/step - accuracy: 0.5956 - auc: 0.5101 - loss: 0.6750 - precision: 0.2778 - recall: 0.0111 - val_accuracy: 0.6082 - val_auc: 0.6145 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 216ms/step - accuracy: 0.6000 - auc: 0.4912 - loss: 0.6777 - precision: 0.3750 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6307 - val_loss: 0.6679 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 218ms/step - accuracy: 0.5996 - auc: 0.5136 - loss: 0.6740 - precision: 0.4255 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6386 - val_loss: 0.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 218ms/step - accuracy: 0.5996 - auc: 0.5152 - loss: 0.6762 - precision: 0.4493 - recall: 0.0343 - val_accuracy: 0.6082 - val_auc: 0.6369 - val_loss: 0.6797 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 218ms/step - accuracy: 0.5987 - auc: 0.5290 - loss: 0.6729 - precision: 0.2857 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6397 - val_loss: 0.6683 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 220ms/step - accuracy: 0.5965 - auc: 0.5243 - loss: 0.6733 - precision: 0.3600 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.6346 - val_loss: 0.6821 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 219ms/step - accuracy: 0.5978 - auc: 0.4989 - loss: 0.6783 - precision: 0.4127 - recall: 0.0288 - val_accuracy: 0.6082 - val_auc: 0.6394 - val_loss: 0.6668 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 219ms/step - accuracy: 0.5666 - auc: 0.4815 - loss: 0.6875 - precision: 0.3536 - recall: 0.1095 - val_accuracy: 0.6082 - val_auc: 0.6482 - val_loss: 0.6675 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 217ms/step - accuracy: 0.6018 - auc: 0.5341 - loss: 0.6715 - precision: 0.4500 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6443 - val_loss: 0.6687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 212ms/step - accuracy: 0.6004 - auc: 0.5180 - loss: 0.6738 - precision: 0.4324 - recall: 0.0177 - val_accuracy: 0.6082 - val_auc: 0.6421 - val_loss: 0.6664 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P0 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p0

# Prediction start time
predict_start_p0 = time.time()

# VGG16 with p0 predictions
prediction_probs_p0 = resnet50_p0.predict(test_dataset_p0)

# Prediction end time
predict_end_p0 = time.time()

# Total prediction time for p0 in seconds
prediction_time_p0 = predict_end_p0 - predict_start_p0
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step

# %%
# Evaluation metrics for Resnet50 with p0
eval_metrics_p0 = resnet50_p0.evaluate(test_dataset_p0, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.5426 - auc: 0.6248 - loss: 0.6968 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p0 = np.where(prediction_probs_p0 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p0 true and predicted values
tn_p0, fp_p0, fn_p0, tp_p0 = confusion_matrix(true_pathology, predictions_p0).ravel()

# Compute specificity using CM
specificity_p0 = tn_p0 / (tn_p0 + fp_p0)

# Compute F1 Score using recall and precision
f1_score_p0 = 0.0
if eval_metrics_p0['precision'] + eval_metrics_p0['recall'] != 0.0:
  f1_score_p0 = (2 * eval_metrics_p0['precision'] * eval_metrics_p0['recall']) / (eval_metrics_p0['precision'] + eval_metrics_p0['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p0 = resnet50_p0.count_params()

# %%
# Generate a results dataframe for results of p0 experiment
results_p0 = generate_results_df('ResNet50', 'View_Independent', 'P0', eval_metrics_p0, specificity_p0, f1_score_p0, training_time_p0, prediction_time_p0, peak_memory_p0, resnet50_params_p0)

# Store p0 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p0)
# Out:
# Stored results for 0    P0
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P0 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P0 pipeline
plot_training_validation_loss(resnet50_p0.history, 'ResNet50 (View-Independent)', 'P0')

# %%
# Training-Validation Accuracy curve for P0 pipeline
plot_training_validation_accuracy(resnet50_p0.history, 'ResNet50  (View-Independent)', 'P0')

# %%
# Precision-Recall curve for P0 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p0, 'ResNet50 (View-Independent)', 'P0')

# %%
# Confusion matrix for P0 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p0, 'ResNet50 (View-Independent)', 'P0')

# %% [markdown]
# ## P1 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * Normalization

# %%
# Select the p1 image preprocessor function from the image preprocessor dictionary
p1 = IMAGE_PREPROCESSORS['P1']

# %%
# Create a tf.data dataset with p1 image preprocessing
train_dataset_p1 = generate_dataset(train_df, 32, p1, 'resnet50', training=True)
val_dataset_p1 = generate_dataset(val_df, 32, p1, 'resnet50', training=False)
test_dataset_p1 = generate_dataset(test_df, 32, p1, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p1 pipeline
resnet50_p1 = create_resnet50_model()
resnet50_p1 = compile_model(resnet50_p1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Train Resnet50 with training dataset for p1 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p1
train_start_p1 = time.time()

# Resnet50 with p1 training for 20 epochs
resnet50_p1.fit(train_dataset_p1, validation_data=val_dataset_p1, epochs=20)

# Memory used in p1
peak_memory_p1 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p1
train_end_p1 = time.time()

# Total training time for p1 in minutes
training_time_p1 = (train_end_p1 - train_start_p1)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 76s 306ms/step - accuracy: 0.5464 - auc: 0.5008 - loss: 0.7252 - precision: 0.3897 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5334 - val_loss: 0.6729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 203ms/step - accuracy: 0.5719 - auc: 0.4935 - loss: 0.6913 - precision: 0.3871 - recall: 0.1327 - val_accuracy: 0.6082 - val_auc: 0.5023 - val_loss: 0.6693 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 203ms/step - accuracy: 0.5846 - auc: 0.4947 - loss: 0.6839 - precision: 0.3787 - recall: 0.0708 - val_accuracy: 0.6082 - val_auc: 0.4960 - val_loss: 0.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 208ms/step - accuracy: 0.5864 - auc: 0.5039 - loss: 0.6797 - precision: 0.4206 - recall: 0.1084 - val_accuracy: 0.6082 - val_auc: 0.5159 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 207ms/step - accuracy: 0.6009 - auc: 0.4918 - loss: 0.6786 - precision: 0.4524 - recall: 0.0210 - val_accuracy: 0.6082 - val_auc: 0.6192 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 207ms/step - accuracy: 0.5978 - auc: 0.5128 - loss: 0.6769 - precision: 0.4321 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.5632 - val_loss: 0.6718 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 211ms/step - accuracy: 0.5890 - auc: 0.4948 - loss: 0.6791 - precision: 0.2615 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5978 - val_loss: 0.6720 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 214ms/step - accuracy: 0.6000 - auc: 0.4907 - loss: 0.6765 - precision: 0.3500 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5864 - val_loss: 0.6682 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 216ms/step - accuracy: 0.5987 - auc: 0.4993 - loss: 0.6764 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6164 - val_loss: 0.6716 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 216ms/step - accuracy: 0.6009 - auc: 0.5089 - loss: 0.6755 - precision: 0.4730 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.6164 - val_loss: 0.6684 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 215ms/step - accuracy: 0.5956 - auc: 0.5101 - loss: 0.6750 - precision: 0.2778 - recall: 0.0111 - val_accuracy: 0.6082 - val_auc: 0.6145 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 216ms/step - accuracy: 0.6000 - auc: 0.4912 - loss: 0.6777 - precision: 0.3750 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6307 - val_loss: 0.6679 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 215ms/step - accuracy: 0.5996 - auc: 0.5136 - loss: 0.6740 - precision: 0.4255 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6386 - val_loss: 0.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 216ms/step - accuracy: 0.5996 - auc: 0.5152 - loss: 0.6762 - precision: 0.4493 - recall: 0.0343 - val_accuracy: 0.6082 - val_auc: 0.6369 - val_loss: 0.6797 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 218ms/step - accuracy: 0.5987 - auc: 0.5290 - loss: 0.6729 - precision: 0.2857 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6397 - val_loss: 0.6683 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 220ms/step - accuracy: 0.5965 - auc: 0.5243 - loss: 0.6733 - precision: 0.3600 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.6346 - val_loss: 0.6821 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 215ms/step - accuracy: 0.5978 - auc: 0.4989 - loss: 0.6783 - precision: 0.4127 - recall: 0.0288 - val_accuracy: 0.6082 - val_auc: 0.6394 - val_loss: 0.6668 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 215ms/step - accuracy: 0.5666 - auc: 0.4815 - loss: 0.6875 - precision: 0.3536 - recall: 0.1095 - val_accuracy: 0.6082 - val_auc: 0.6482 - val_loss: 0.6675 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 213ms/step - accuracy: 0.6018 - auc: 0.5341 - loss: 0.6715 - precision: 0.4500 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6443 - val_loss: 0.6687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 214ms/step - accuracy: 0.6004 - auc: 0.5180 - loss: 0.6738 - precision: 0.4324 - recall: 0.0177 - val_accuracy: 0.6082 - val_auc: 0.6421 - val_loss: 0.6664 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P1 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p1

# Prediction start time
predict_start_p1 = time.time()

# Resnet50 with p1 predictions
prediction_probs_p1 = resnet50_p1.predict(test_dataset_p1)

# Prediction end time
predict_end_p1 = time.time()

# Total prediction time for p1 in seconds
prediction_time_p1 = predict_end_p1 - predict_start_p1
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step

# %%
# Evaluation metrics for Resnet50 with p1
eval_metrics_p1 = resnet50_p1.evaluate(test_dataset_p1, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.5426 - auc: 0.6248 - loss: 0.6968 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p1 = np.where(prediction_probs_p1 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p1 true and predicted values
tn_p1, fp_p1, fn_p1, tp_p1 = confusion_matrix(true_pathology, predictions_p1).ravel()

# Compute specificity using CM
specificity_p1 = tn_p1 / (tn_p1 + fp_p1)

# Compute F1 Score using recall and precision
f1_score_p1 = 0.0
if eval_metrics_p1['precision'] + eval_metrics_p1['recall'] != 0.0:
  f1_score_p1 = (2 * eval_metrics_p1['precision'] * eval_metrics_p1['recall']) / (eval_metrics_p1['precision'] + eval_metrics_p1['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p1 = resnet50_p1.count_params()

# %%
# Generate a results dataframe for results of p1 experiment
results_p1 = generate_results_df('ResNet50', 'View_Independent', 'P1', eval_metrics_p1, specificity_p1, f1_score_p1, training_time_p1, prediction_time_p1, peak_memory_p1, resnet50_params_p1)

# Store p1 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p1)
# Out:
# Stored results for 0    P1
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P1 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P1 pipeline
plot_training_validation_loss(resnet50_p1.history, 'ResNet50 (View-Independent)', 'P1')

# %%
# Training-Validation Accuracy curve for P1 pipeline
plot_training_validation_accuracy(resnet50_p1.history, 'ResNet50 (View-Independent)', 'P1')

# %%
# Precision-Recall curve for P1 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p1, 'ResNet50 (View-Independent)', 'P1')

# %%
# Confusion matrix for P1 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p1, 'ResNet50 (View-Independent)', 'P1')

# %% [markdown]
# ## P2 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * CLAHE
# * Normalization

# %%
# Select the p2 image preprocessor function from the image preprocessor dictionary
p2 = IMAGE_PREPROCESSORS['P2']

# %%
# Create a tf.data dataset with p2 image preprocessing
train_dataset_p2 = generate_dataset(train_df, 32, p2, 'resnet50', training=True)
val_dataset_p2 = generate_dataset(val_df, 32, p2, 'resnet50', training=False)
test_dataset_p2 = generate_dataset(test_df, 32, p2, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p2 pipeline
resnet50_p2 = create_resnet50_model()
resnet50_p2 = compile_model(resnet50_p2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Train Resnet50 with training dataset for p2 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p2
train_start_p2 = time.time()

# Resnet50 with p2 training for 20 epochs
resnet50_p2.fit(train_dataset_p2, validation_data=val_dataset_p2, epochs=20)

# Memory used in p2
peak_memory_p2 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p2
train_end_p2 = time.time()

# Total training time for p2 in minutes
training_time_p2 = (train_end_p2 - train_start_p2)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 84s 254ms/step - accuracy: 0.5473 - auc: 0.5007 - loss: 0.7250 - precision: 0.3910 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5512 - val_loss: 0.6727 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 227ms/step - accuracy: 0.5705 - auc: 0.4943 - loss: 0.6911 - precision: 0.3826 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.5442 - val_loss: 0.6691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 218ms/step - accuracy: 0.5864 - auc: 0.4950 - loss: 0.6838 - precision: 0.3918 - recall: 0.0741 - val_accuracy: 0.6082 - val_auc: 0.5375 - val_loss: 0.6771 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 229ms/step - accuracy: 0.5864 - auc: 0.5057 - loss: 0.6794 - precision: 0.4199 - recall: 0.1073 - val_accuracy: 0.6082 - val_auc: 0.5724 - val_loss: 0.6702 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 218ms/step - accuracy: 0.6009 - auc: 0.4938 - loss: 0.6782 - precision: 0.4545 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6003 - val_loss: 0.6692 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 69s 237ms/step - accuracy: 0.5974 - auc: 0.5160 - loss: 0.6764 - precision: 0.4250 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.6202 - val_loss: 0.6710 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 68s 219ms/step - accuracy: 0.5899 - auc: 0.4968 - loss: 0.6785 - precision: 0.2623 - recall: 0.0177 - val_accuracy: 0.6082 - val_auc: 0.6105 - val_loss: 0.6712 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 236ms/step - accuracy: 0.6004 - auc: 0.4945 - loss: 0.6759 - precision: 0.3810 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.6147 - val_loss: 0.6674 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 216ms/step - accuracy: 0.5987 - auc: 0.5022 - loss: 0.6760 - precision: 0.2857 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6149 - val_loss: 0.6708 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 221ms/step - accuracy: 0.6000 - auc: 0.5134 - loss: 0.6746 - precision: 0.4595 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.6288 - val_loss: 0.6675 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 70s 227ms/step - accuracy: 0.5960 - auc: 0.5166 - loss: 0.6740 - precision: 0.2973 - recall: 0.0122 - val_accuracy: 0.6082 - val_auc: 0.6376 - val_loss: 0.6686 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 218ms/step - accuracy: 0.5991 - auc: 0.4977 - loss: 0.6769 - precision: 0.3462 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6316 - val_loss: 0.6667 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 221ms/step - accuracy: 0.5991 - auc: 0.5252 - loss: 0.6725 - precision: 0.4200 - recall: 0.0232 - val_accuracy: 0.6082 - val_auc: 0.6368 - val_loss: 0.6767 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 86s 241ms/step - accuracy: 0.5996 - auc: 0.5198 - loss: 0.6753 - precision: 0.4521 - recall: 0.0365 - val_accuracy: 0.6082 - val_auc: 0.6312 - val_loss: 0.6776 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 217ms/step - accuracy: 0.6009 - auc: 0.5365 - loss: 0.6714 - precision: 0.4000 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.6378 - val_loss: 0.6667 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 68s 231ms/step - accuracy: 0.5978 - auc: 0.5321 - loss: 0.6720 - precision: 0.3962 - recall: 0.0232 - val_accuracy: 0.6082 - val_auc: 0.6251 - val_loss: 0.6810 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 210ms/step - accuracy: 0.5978 - auc: 0.5074 - loss: 0.6769 - precision: 0.4203 - recall: 0.0321 - val_accuracy: 0.6082 - val_auc: 0.6411 - val_loss: 0.6651 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 209ms/step - accuracy: 0.5675 - auc: 0.4866 - loss: 0.6863 - precision: 0.3592 - recall: 0.1128 - val_accuracy: 0.6082 - val_auc: 0.6407 - val_loss: 0.6657 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 68s 231ms/step - accuracy: 0.6026 - auc: 0.5431 - loss: 0.6698 - precision: 0.5000 - recall: 0.0155 - val_accuracy: 0.6082 - val_auc: 0.6322 - val_loss: 0.6671 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 217ms/step - accuracy: 0.6026 - auc: 0.5301 - loss: 0.6721 - precision: 0.5000 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6424 - val_loss: 0.6646 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P2 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p2

# Prediction start time
predict_start_p2 = time.time()

# Resnet50 with p2 predictions
prediction_probs_p2 = resnet50_p2.predict(test_dataset_p2)

# Prediction end time
predict_end_p2 = time.time()

# Total prediction time for p2 in seconds
prediction_time_p2 = predict_end_p2 - predict_start_p2
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step

# %%
# Evaluation metrics for Resnet50 with p2
eval_metrics_p2 = resnet50_p2.evaluate(test_dataset_p2, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.5426 - auc: 0.6190 - loss: 0.6957 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p2 = np.where(prediction_probs_p2 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p2 true and predicted values
tn_p2, fp_p2, fn_p2, tp_p2 = confusion_matrix(true_pathology, predictions_p2).ravel()

# Compute specificity using CM
specificity_p2 = tn_p2 / (tn_p2 + fp_p2)

# Compute F1 Score using recall and precision
f1_score_p2 = 0.0
if eval_metrics_p2['precision'] + eval_metrics_p2['recall'] != 0.0:
  f1_score_p2 = (2 * eval_metrics_p2['precision'] * eval_metrics_p2['recall']) / (eval_metrics_p2['precision'] + eval_metrics_p2['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p2 = resnet50_p2.count_params()

# %%
# Generate a results dataframe for results of p2 experiment
results_p2 = generate_results_df('ResNet50', 'View_Independent', 'P2', eval_metrics_p2, specificity_p2, f1_score_p2, training_time_p2, prediction_time_p2, peak_memory_p2, resnet50_params_p2)

# Store p2 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p2)
# Out:
# Stored results for 0    P2
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P2 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P2 pipeline
plot_training_validation_loss(resnet50_p2.history, 'ResNet50 (View-Independent)', 'P2')

# %%
# Training-Validation Accuracy curve for P2 pipeline
plot_training_validation_accuracy(resnet50_p2.history, 'ResNet50 (View-Independent)', 'P2')

# %%
# Precision-Recall curve for P2 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p2, 'ResNet50 (View-Independent)', 'P2')

# %%
# Confusion matrix for P2 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p2, 'ResNet50 (View-Independent)', 'P2')

# %% [markdown]
# ## P3 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Gamma Correction
# * Normalization

# %%
# Select the p3 image preprocessor function from the image preprocessor dictionary
p3 = IMAGE_PREPROCESSORS['P3']

# %%
# Create a tf.data dataset with p3 image preprocessing
train_dataset_p3 = generate_dataset(train_df, 32, p3, 'resnet50', training=True)
val_dataset_p3 = generate_dataset(val_df, 32, p3, 'resnet50', training=False)
test_dataset_p3 = generate_dataset(test_df, 32, p3, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p3 pipeline
resnet50_p3 = create_resnet50_model()
resnet50_p3 = compile_model(resnet50_p3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Train Resnet50 with training dataset for p3 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p3
train_start_p3 = time.time()

# Resnet50 with p3 training for 20 epochs
resnet50_p3.fit(train_dataset_p3, validation_data=val_dataset_p3, epochs=20)

# Memory used in p3
peak_memory_p3 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p3
train_end_p3 = time.time()

# Total training time for p3 in minutes
training_time_p3 = (train_end_p3 - train_start_p3)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 73s 262ms/step - accuracy: 0.5459 - auc: 0.5005 - loss: 0.7254 - precision: 0.3890 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5165 - val_loss: 0.6730 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 62s 269ms/step - accuracy: 0.5714 - auc: 0.4929 - loss: 0.6914 - precision: 0.3851 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.5030 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 254ms/step - accuracy: 0.5846 - auc: 0.4941 - loss: 0.6842 - precision: 0.3801 - recall: 0.0719 - val_accuracy: 0.6082 - val_auc: 0.4940 - val_loss: 0.6777 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 251ms/step - accuracy: 0.5864 - auc: 0.5031 - loss: 0.6799 - precision: 0.4199 - recall: 0.1073 - val_accuracy: 0.6082 - val_auc: 0.5026 - val_loss: 0.6707 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 261ms/step - accuracy: 0.6009 - auc: 0.4886 - loss: 0.6791 - precision: 0.4500 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.5884 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 251ms/step - accuracy: 0.5969 - auc: 0.5109 - loss: 0.6773 - precision: 0.4198 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.5532 - val_loss: 0.6723 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 244ms/step - accuracy: 0.5899 - auc: 0.4919 - loss: 0.6796 - precision: 0.2698 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5380 - val_loss: 0.6727 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 245ms/step - accuracy: 0.5996 - auc: 0.4876 - loss: 0.6770 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5403 - val_loss: 0.6689 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 251ms/step - accuracy: 0.5996 - auc: 0.4957 - loss: 0.6770 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5831 - val_loss: 0.6724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 249ms/step - accuracy: 0.5996 - auc: 0.5053 - loss: 0.6760 - precision: 0.4521 - recall: 0.0365 - val_accuracy: 0.6082 - val_auc: 0.5952 - val_loss: 0.6693 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 307ms/step - accuracy: 0.5938 - auc: 0.5038 - loss: 0.6760 - precision: 0.2222 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.5776 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 244ms/step - accuracy: 0.5987 - auc: 0.4842 - loss: 0.6787 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5476 - val_loss: 0.6691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 307ms/step - accuracy: 0.5969 - auc: 0.5072 - loss: 0.6750 - precision: 0.3488 - recall: 0.0166 - val_accuracy: 0.6082 - val_auc: 0.5585 - val_loss: 0.6787 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 245ms/step - accuracy: 0.5991 - auc: 0.5115 - loss: 0.6771 - precision: 0.4429 - recall: 0.0343 - val_accuracy: 0.6082 - val_auc: 0.5666 - val_loss: 0.6811 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 246ms/step - accuracy: 0.5991 - auc: 0.5234 - loss: 0.6738 - precision: 0.3000 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6136 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 251ms/step - accuracy: 0.5974 - auc: 0.5179 - loss: 0.6743 - precision: 0.3750 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.5805 - val_loss: 0.6836 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 62s 258ms/step - accuracy: 0.5978 - auc: 0.4932 - loss: 0.6794 - precision: 0.4035 - recall: 0.0254 - val_accuracy: 0.6082 - val_auc: 0.5934 - val_loss: 0.6684 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 269ms/step - accuracy: 0.5666 - auc: 0.4761 - loss: 0.6888 - precision: 0.3514 - recall: 0.1073 - val_accuracy: 0.6082 - val_auc: 0.6271 - val_loss: 0.6692 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 237ms/step - accuracy: 0.5982 - auc: 0.5274 - loss: 0.6729 - precision: 0.1875 - recall: 0.0033 - val_accuracy: 0.6082 - val_auc: 0.6057 - val_loss: 0.6706 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 62s 251ms/step - accuracy: 0.6000 - auc: 0.5097 - loss: 0.6754 - precision: 0.4118 - recall: 0.0155 - val_accuracy: 0.6082 - val_auc: 0.6150 - val_loss: 0.6682 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P3 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p3

# Prediction start time
predict_start_p3 = time.time()

# Resnet50 with p3 predictions
prediction_probs_p3 = resnet50_p3.predict(test_dataset_p3)

# Prediction end time
predict_end_p3 = time.time()

# Total prediction time for p3 in seconds
prediction_time_p3 = predict_end_p3 - predict_start_p3
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step

# %%
# Evaluation metrics for Resnet50 with p3
eval_metrics_p3 = resnet50_p3.evaluate(test_dataset_p3, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 154ms/step - accuracy: 0.5426 - auc: 0.6159 - loss: 0.6982 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p3 = np.where(prediction_probs_p3 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p3 true and predicted values
tn_p3, fp_p3, fn_p3, tp_p3 = confusion_matrix(true_pathology, predictions_p3).ravel()

# Compute specificity using CM
specificity_p3 = tn_p3 / (tn_p3 + fp_p3)

# Compute F1 Score using recall and precision
f1_score_p3 = 0.0
if eval_metrics_p3['precision'] + eval_metrics_p3['recall'] != 0.0:
  f1_score_p3 = (2 * eval_metrics_p3['precision'] * eval_metrics_p3['recall']) / (eval_metrics_p3['precision'] + eval_metrics_p3['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p3 = resnet50_p3.count_params()

# %%
# Generate a results dataframe for results of p3 experiment
results_p3 = generate_results_df('ResNet50', 'View_Independent', 'P3', eval_metrics_p3, specificity_p3, f1_score_p3, training_time_p3, prediction_time_p3, peak_memory_p3, resnet50_params_p3)

# Store p3 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p3)
# Out:
# Stored results for 0    P3
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P3 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P3 pipeline
plot_training_validation_loss(resnet50_p3.history, 'ResNet50 (View-Independent)', 'P3')

# %%
# Training-Validation Accuracy curve for P3 pipeline
plot_training_validation_accuracy(resnet50_p3.history, 'ResNet50 (View-Independent)', 'P3')

# %%
# Precision-Recall curve for P3 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p3, 'ResNet50 (View-Independent)', 'P3')

# %%
# Confusion matrix for P3 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p3, 'ResNet50 (View-Independent)', 'P3')

# %% [markdown]
# ## P4 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Median Blur
# * Normalization

# %%
# Select the p4 image preprocessor function from the image preprocessor dictionary
p4 = IMAGE_PREPROCESSORS['P4']

# %%
# Create a tf.data dataset with p4 image preprocessing
train_dataset_p4 = generate_dataset(train_df, 32, p4, 'resnet50', training=True)
val_dataset_p4 = generate_dataset(val_df, 32, p4, 'resnet50', training=False)
test_dataset_p4 = generate_dataset(test_df, 32, p4, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p4 pipeline
resnet50_p4 = create_resnet50_model()
resnet50_p4 = compile_model(resnet50_p4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Train ResNet50 with training dataset for p4 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p4
train_start_p4 = time.time()

# ResNet50 with p4 training for 20 epochs
resnet50_p4.fit(train_dataset_p4, validation_data=val_dataset_p4, epochs=20)

# Memory used in p4
peak_memory_p4 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p4
train_end_p4 = time.time()

# Total training time for p4 in minutes
training_time_p4 = (train_end_p4 - train_start_p4)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 76s 253ms/step - accuracy: 0.5464 - auc: 0.5007 - loss: 0.7253 - precision: 0.3897 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5273 - val_loss: 0.6729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 203ms/step - accuracy: 0.5705 - auc: 0.4933 - loss: 0.6913 - precision: 0.3826 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.5031 - val_loss: 0.6692 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 202ms/step - accuracy: 0.5846 - auc: 0.4946 - loss: 0.6840 - precision: 0.3787 - recall: 0.0708 - val_accuracy: 0.6082 - val_auc: 0.5028 - val_loss: 0.6776 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 202ms/step - accuracy: 0.5864 - auc: 0.5038 - loss: 0.6797 - precision: 0.4206 - recall: 0.1084 - val_accuracy: 0.6082 - val_auc: 0.5125 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 198ms/step - accuracy: 0.6009 - auc: 0.4916 - loss: 0.6787 - precision: 0.4524 - recall: 0.0210 - val_accuracy: 0.6082 - val_auc: 0.6028 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 198ms/step - accuracy: 0.5978 - auc: 0.5127 - loss: 0.6769 - precision: 0.4321 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.5773 - val_loss: 0.6718 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 199ms/step - accuracy: 0.5890 - auc: 0.4946 - loss: 0.6791 - precision: 0.2615 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5921 - val_loss: 0.6721 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 198ms/step - accuracy: 0.6000 - auc: 0.4902 - loss: 0.6766 - precision: 0.3500 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5941 - val_loss: 0.6683 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 199ms/step - accuracy: 0.5987 - auc: 0.4993 - loss: 0.6765 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6175 - val_loss: 0.6717 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 199ms/step - accuracy: 0.6013 - auc: 0.5088 - loss: 0.6756 - precision: 0.4795 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.6124 - val_loss: 0.6685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 197ms/step - accuracy: 0.5952 - auc: 0.5087 - loss: 0.6752 - precision: 0.2703 - recall: 0.0111 - val_accuracy: 0.6082 - val_auc: 0.6170 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 198ms/step - accuracy: 0.5996 - auc: 0.4911 - loss: 0.6777 - precision: 0.3600 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6196 - val_loss: 0.6681 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 196ms/step - accuracy: 0.5991 - auc: 0.5124 - loss: 0.6742 - precision: 0.4167 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6214 - val_loss: 0.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 198ms/step - accuracy: 0.6000 - auc: 0.5141 - loss: 0.6763 - precision: 0.4545 - recall: 0.0332 - val_accuracy: 0.6082 - val_auc: 0.6321 - val_loss: 0.6800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 197ms/step - accuracy: 0.5987 - auc: 0.5278 - loss: 0.6730 - precision: 0.2857 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6258 - val_loss: 0.6685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 196ms/step - accuracy: 0.5978 - auc: 0.5236 - loss: 0.6735 - precision: 0.3830 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.6361 - val_loss: 0.6821 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 198ms/step - accuracy: 0.5982 - auc: 0.4984 - loss: 0.6784 - precision: 0.4167 - recall: 0.0277 - val_accuracy: 0.6082 - val_auc: 0.6415 - val_loss: 0.6670 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 198ms/step - accuracy: 0.5662 - auc: 0.4806 - loss: 0.6875 - precision: 0.3513 - recall: 0.1084 - val_accuracy: 0.6082 - val_auc: 0.6386 - val_loss: 0.6677 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 201ms/step - accuracy: 0.6013 - auc: 0.5332 - loss: 0.6717 - precision: 0.4211 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.6347 - val_loss: 0.6689 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 203ms/step - accuracy: 0.6009 - auc: 0.5168 - loss: 0.6740 - precision: 0.4474 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.6266 - val_loss: 0.6666 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P4 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p4

# Prediction start time
predict_start_p4 = time.time()

# Resnet50 with p4 predictions
prediction_probs_p4 = resnet50_p4.predict(test_dataset_p4)

# Prediction end time
predict_end_p4 = time.time()

# Total prediction time for p4 in seconds
prediction_time_p4 = predict_end_p4 - predict_start_p4
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step

# %%
# Evaluation metrics for Resnet50 with p4
eval_metrics_p4 = resnet50_p4.evaluate(test_dataset_p4, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.5426 - auc: 0.6302 - loss: 0.6969 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p4 = np.where(prediction_probs_p4 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p4 true and predicted values
tn_p4, fp_p4, fn_p4, tp_p4 = confusion_matrix(true_pathology, predictions_p4).ravel()

# Compute specificity using CM
specificity_p4 = tn_p4 / (tn_p4 + fp_p4)

# Compute F1 Score using recall and precision
f1_score_p4 = 0.0
if eval_metrics_p4['precision'] + eval_metrics_p4['recall'] != 0.0:
  f1_score_p4 = (2 * eval_metrics_p4['precision'] * eval_metrics_p4['recall']) / (eval_metrics_p4['precision'] + eval_metrics_p4['recall'])

# Parameters of ResNet50 View-Independent model
resnet50_params_p4 = resnet50_p4.count_params()

# %%
# Generate a results dataframe for results of p4 experiment
results_p4 = generate_results_df('ResNet50', 'View_Independent', 'P4', eval_metrics_p4, specificity_p4, f1_score_p4, training_time_p4, prediction_time_p4, peak_memory_p4, resnet50_params_p4)

# Store p4 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p4)
# Out:
# Stored results for 0    P4
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P4 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P4 pipeline
plot_training_validation_loss(resnet50_p4.history, 'ResNet50 (View-Independent)', 'P4')

# %%
# Training-Validation Accuracy curve for P4 pipeline
plot_training_validation_accuracy(resnet50_p4.history, 'ResNet50 (View-Independent)', 'P4')

# %%
# Precision-Recall curve for P4 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p4, 'ResNet50 (View-Independent)', 'P4')

# %%
# Confusion matrix for P4 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p4, 'ResNet50 (View-Independent)', 'P4')

# %% [markdown]
# ## P5 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * Gamma Correction
# * Normalization

# %%
# Select the p5 image preprocessor function from the image preprocessor dictionary
p5 = IMAGE_PREPROCESSORS['P5']

# %%
# Create a tf.data dataset with p5 image preprocessing
train_dataset_p5 = generate_dataset(train_df, 32, p5, 'resnet50', training=True)
val_dataset_p5 = generate_dataset(val_df, 32, p5, 'resnet50', training=False)
test_dataset_p5 = generate_dataset(test_df, 32, p5, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p5 pipeline
resnet50_p5 = create_resnet50_model()
resnet50_p5 = compile_model(resnet50_p5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Train ResNet50 with training dataset for p5 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p5
train_start_p5 = time.time()

# ResNet50 with p5 training for 20 epochs
resnet50_p5.fit(train_dataset_p5, validation_data=val_dataset_p5, epochs=20)

# Memory used in p5
peak_memory_p5 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p5
train_end_p5 = time.time()

# Total training time for p5 in minutes
training_time_p5 = (train_end_p5 - train_start_p5)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 267ms/step - accuracy: 0.5459 - auc: 0.5005 - loss: 0.7254 - precision: 0.3890 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5165 - val_loss: 0.6730 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 225ms/step - accuracy: 0.5714 - auc: 0.4929 - loss: 0.6914 - precision: 0.3851 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.5030 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 239ms/step - accuracy: 0.5846 - auc: 0.4941 - loss: 0.6842 - precision: 0.3801 - recall: 0.0719 - val_accuracy: 0.6082 - val_auc: 0.4940 - val_loss: 0.6777 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 225ms/step - accuracy: 0.5864 - auc: 0.5031 - loss: 0.6799 - precision: 0.4199 - recall: 0.1073 - val_accuracy: 0.6082 - val_auc: 0.5026 - val_loss: 0.6707 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 249ms/step - accuracy: 0.6009 - auc: 0.4886 - loss: 0.6791 - precision: 0.4500 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.5884 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 224ms/step - accuracy: 0.5969 - auc: 0.5109 - loss: 0.6773 - precision: 0.4198 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.5532 - val_loss: 0.6723 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 246ms/step - accuracy: 0.5899 - auc: 0.4919 - loss: 0.6796 - precision: 0.2698 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5380 - val_loss: 0.6727 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 63s 228ms/step - accuracy: 0.5996 - auc: 0.4876 - loss: 0.6770 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5403 - val_loss: 0.6689 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 233ms/step - accuracy: 0.5996 - auc: 0.4957 - loss: 0.6770 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5831 - val_loss: 0.6724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.5996 - auc: 0.5053 - loss: 0.6760 - precision: 0.4521 - recall: 0.0365 - val_accuracy: 0.6082 - val_auc: 0.5952 - val_loss: 0.6693 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 234ms/step - accuracy: 0.5938 - auc: 0.5038 - loss: 0.6760 - precision: 0.2222 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.5776 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 233ms/step - accuracy: 0.5987 - auc: 0.4842 - loss: 0.6787 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5476 - val_loss: 0.6691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 237ms/step - accuracy: 0.5969 - auc: 0.5072 - loss: 0.6750 - precision: 0.3488 - recall: 0.0166 - val_accuracy: 0.6082 - val_auc: 0.5585 - val_loss: 0.6787 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 84s 246ms/step - accuracy: 0.5991 - auc: 0.5115 - loss: 0.6771 - precision: 0.4429 - recall: 0.0343 - val_accuracy: 0.6082 - val_auc: 0.5666 - val_loss: 0.6811 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 63s 230ms/step - accuracy: 0.5991 - auc: 0.5234 - loss: 0.6738 - precision: 0.3000 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6136 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 63s 224ms/step - accuracy: 0.5974 - auc: 0.5179 - loss: 0.6743 - precision: 0.3750 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.5805 - val_loss: 0.6836 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 251ms/step - accuracy: 0.5978 - auc: 0.4932 - loss: 0.6794 - precision: 0.4035 - recall: 0.0254 - val_accuracy: 0.6082 - val_auc: 0.5934 - val_loss: 0.6684 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 62s 225ms/step - accuracy: 0.5666 - auc: 0.4761 - loss: 0.6888 - precision: 0.3514 - recall: 0.1073 - val_accuracy: 0.6082 - val_auc: 0.6271 - val_loss: 0.6692 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 294ms/step - accuracy: 0.5982 - auc: 0.5274 - loss: 0.6729 - precision: 0.1875 - recall: 0.0033 - val_accuracy: 0.6082 - val_auc: 0.6057 - val_loss: 0.6706 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 62s 223ms/step - accuracy: 0.6000 - auc: 0.5097 - loss: 0.6754 - precision: 0.4118 - recall: 0.0155 - val_accuracy: 0.6082 - val_auc: 0.6150 - val_loss: 0.6682 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P5 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p5

# Prediction start time
predict_start_p5 = time.time()

# Resnet50 with p5 predictions
prediction_probs_p5 = resnet50_p5.predict(test_dataset_p5)

# Prediction end time
predict_end_p5 = time.time()

# Total prediction time for p5 in seconds
prediction_time_p5 = predict_end_p5 - predict_start_p5
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step

# %%
# Evaluation metrics for Resnet50 with p5
eval_metrics_p5 = resnet50_p5.evaluate(test_dataset_p5, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.5426 - auc: 0.6159 - loss: 0.6982 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p5 = np.where(prediction_probs_p5 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p5 true and predicted values
tn_p5, fp_p5, fn_p5, tp_p5 = confusion_matrix(true_pathology, predictions_p5).ravel()

# Compute specificity using CM
specificity_p5 = tn_p5 / (tn_p5 + fp_p5)

# Compute F1 Score using recall and precision
f1_score_p5 = 0.0
if eval_metrics_p5['precision'] + eval_metrics_p5['recall'] != 0.0:
  f1_score_p5 = (2 * eval_metrics_p5['precision'] * eval_metrics_p5['recall']) / (eval_metrics_p5['precision'] + eval_metrics_p5['recall'])

# Parameters of ResNet50 View-Independent model
resnet50_params_p5 = resnet50_p5.count_params()

# %%
# Generate a results dataframe for results of p5 experiment
results_p5 = generate_results_df('ResNet50', 'View_Independent', 'P5', eval_metrics_p5, specificity_p5, f1_score_p5, training_time_p5, prediction_time_p5, peak_memory_p5, resnet50_params_p5)

# Store p5 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p5)
# Out:
# Stored results for 0    P5
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P5 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P5 pipeline
plot_training_validation_loss(resnet50_p5.history, 'ResNet50 (View-Independent)', 'P5')

# %%
# Training-Validation Accuracy curve for P5 pipeline
plot_training_validation_accuracy(resnet50_p5.history, 'ResNet50 (View-Independent)', 'P5')

# %%
# Precision-Recall curve for P5 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p5, 'ResNet50 (View-Independent)', 'P5')

# %%
# Confusion matrix for P5 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p5, 'ResNet50 (View-Independent)', 'P5')

# %% [markdown]
# ## P6 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * Median Blur
# * Normalization

# %%
# Select the p6 image preprocessor function from the image preprocessor dictionary
p6 = IMAGE_PREPROCESSORS['P6']

# %%
# Create a tf.data dataset with p6 image preprocessing
train_dataset_p6 = generate_dataset(train_df, 32, p6, 'resnet50', training=True)
val_dataset_p6 = generate_dataset(val_df, 32, p6, 'resnet50', training=False)
test_dataset_p6 = generate_dataset(test_df, 32, p6, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p6 pipeline
resnet50_p6 = create_resnet50_model()
resnet50_p6 = compile_model(resnet50_p6)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
# Train Resnet50 with training dataset for p6 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p6
train_start_p6 = time.time()

# Resnet50 with p6 training for 20 epochs
resnet50_p6.fit(train_dataset_p6, validation_data=val_dataset_p6, epochs=20)

# Memory used in p6
peak_memory_p6 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p6
train_end_p6 = time.time()

# Total training time for p6 in minutes
training_time_p6 = (train_end_p6 - train_start_p6)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 71s 243ms/step - accuracy: 0.5464 - auc: 0.5007 - loss: 0.7253 - precision: 0.3897 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5273 - val_loss: 0.6729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 212ms/step - accuracy: 0.5705 - auc: 0.4933 - loss: 0.6913 - precision: 0.3826 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.5031 - val_loss: 0.6692 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 216ms/step - accuracy: 0.5846 - auc: 0.4946 - loss: 0.6840 - precision: 0.3787 - recall: 0.0708 - val_accuracy: 0.6082 - val_auc: 0.5028 - val_loss: 0.6776 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 224ms/step - accuracy: 0.5864 - auc: 0.5038 - loss: 0.6797 - precision: 0.4206 - recall: 0.1084 - val_accuracy: 0.6082 - val_auc: 0.5125 - val_loss: 0.6705 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 215ms/step - accuracy: 0.6009 - auc: 0.4916 - loss: 0.6787 - precision: 0.4524 - recall: 0.0210 - val_accuracy: 0.6082 - val_auc: 0.6028 - val_loss: 0.6697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 225ms/step - accuracy: 0.5978 - auc: 0.5127 - loss: 0.6769 - precision: 0.4321 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.5773 - val_loss: 0.6718 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 215ms/step - accuracy: 0.5890 - auc: 0.4946 - loss: 0.6791 - precision: 0.2615 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5921 - val_loss: 0.6721 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 223ms/step - accuracy: 0.6000 - auc: 0.4902 - loss: 0.6766 - precision: 0.3500 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5941 - val_loss: 0.6683 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 216ms/step - accuracy: 0.5987 - auc: 0.4993 - loss: 0.6765 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6175 - val_loss: 0.6717 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 223ms/step - accuracy: 0.6013 - auc: 0.5088 - loss: 0.6756 - precision: 0.4795 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.6124 - val_loss: 0.6685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 56s 217ms/step - accuracy: 0.5952 - auc: 0.5087 - loss: 0.6752 - precision: 0.2703 - recall: 0.0111 - val_accuracy: 0.6082 - val_auc: 0.6170 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 225ms/step - accuracy: 0.5996 - auc: 0.4911 - loss: 0.6777 - precision: 0.3600 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6196 - val_loss: 0.6681 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 215ms/step - accuracy: 0.5991 - auc: 0.5124 - loss: 0.6742 - precision: 0.4167 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6214 - val_loss: 0.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 226ms/step - accuracy: 0.6000 - auc: 0.5141 - loss: 0.6763 - precision: 0.4545 - recall: 0.0332 - val_accuracy: 0.6082 - val_auc: 0.6321 - val_loss: 0.6800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 214ms/step - accuracy: 0.5987 - auc: 0.5278 - loss: 0.6730 - precision: 0.2857 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6258 - val_loss: 0.6685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 223ms/step - accuracy: 0.5978 - auc: 0.5236 - loss: 0.6735 - precision: 0.3830 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.6361 - val_loss: 0.6821 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 217ms/step - accuracy: 0.5982 - auc: 0.4984 - loss: 0.6784 - precision: 0.4167 - recall: 0.0277 - val_accuracy: 0.6082 - val_auc: 0.6415 - val_loss: 0.6670 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 223ms/step - accuracy: 0.5662 - auc: 0.4806 - loss: 0.6875 - precision: 0.3513 - recall: 0.1084 - val_accuracy: 0.6082 - val_auc: 0.6386 - val_loss: 0.6677 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 215ms/step - accuracy: 0.6013 - auc: 0.5332 - loss: 0.6717 - precision: 0.4211 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.6347 - val_loss: 0.6689 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 222ms/step - accuracy: 0.6009 - auc: 0.5168 - loss: 0.6740 - precision: 0.4474 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.6266 - val_loss: 0.6666 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P6 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p6

# Prediction start time
predict_start_p6 = time.time()

# Resnet50 with p6 predictions
prediction_probs_p6 = resnet50_p6.predict(test_dataset_p6)

# Prediction end time
predict_end_p6 = time.time()

# Total prediction time for p6 in seconds
prediction_time_p6 = predict_end_p6 - predict_start_p6
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 142ms/step

# %%
# Evaluation metrics for Resnet50 with p6
eval_metrics_p6 = resnet50_p6.evaluate(test_dataset_p6, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.5426 - auc: 0.6302 - loss: 0.6969 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p6 = np.where(prediction_probs_p6 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p6 true and predicted values
tn_p6, fp_p6, fn_p6, tp_p6 = confusion_matrix(true_pathology, predictions_p6).ravel()

# Compute specificity using CM
specificity_p6 = tn_p6 / (tn_p6 + fp_p6)

# Compute F1 Score using recall and precision
f1_score_p6 = 0.0
if eval_metrics_p6['precision'] + eval_metrics_p6['recall'] != 0.0:
  f1_score_p6 = (2 * eval_metrics_p6['precision'] * eval_metrics_p6['recall']) / (eval_metrics_p6['precision'] + eval_metrics_p6['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p6 = resnet50_p6.count_params()

# %%
# Generate a results dataframe for results of p6 experiment
results_p6 = generate_results_df('ResNet50', 'View_Independent', 'P6', eval_metrics_p6, specificity_p6, f1_score_p6, training_time_p6, prediction_time_p6, peak_memory_p6, resnet50_params_p6)

# Store p6 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p6)
# Out:
# Stored results for 0    P6
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P6 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P6 pipeline
plot_training_validation_loss(resnet50_p6.history, 'ResNet50 (View-Independent)', 'P6')

# %%
# Training-Validation Accuracy curve for P6 pipeline
plot_training_validation_accuracy(resnet50_p6.history, 'ResNet50 (View-Independent)', 'P6')

# %%
# Precision-Recall curve for P6 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p6, 'ResNet50 (View-Independent)', 'P6')

# %%
# Confusion matrix for P6 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p6, 'ResNet50 (View-Independent)', 'P6')

# %% [markdown]
# ## P7 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * CLAHE
# * Gamma Correction
# * Normalization

# %%
# Select the p7 image preprocessor function from the image preprocessor dictionary
p7 = IMAGE_PREPROCESSORS['P7']

# %%
# Create a tf.data dataset with p7 image preprocessing
train_dataset_p7 = generate_dataset(train_df, 32, p7, 'resnet50', training=True)
val_dataset_p7 = generate_dataset(val_df, 32, p7, 'resnet50', training=False)
test_dataset_p7 = generate_dataset(test_df, 32, p7, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p7 pipeline
resnet50_p7 = create_resnet50_model()
resnet50_p7 = compile_model(resnet50_p7)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Train Resnet50 with training dataset for p7 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p7
train_start_p7 = time.time()

# Resnet50 with p7 training for 20 epochs
resnet50_p7.fit(train_dataset_p7, validation_data=val_dataset_p7, epochs=20)

# Memory used in p7
peak_memory_p7 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p7
train_end_p7 = time.time()

# Total training time for p7 in minutes
training_time_p7 = (train_end_p7 - train_start_p7)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 314ms/step - accuracy: 0.5464 - auc: 0.5003 - loss: 0.7253 - precision: 0.3897 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5272 - val_loss: 0.6729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 227ms/step - accuracy: 0.5705 - auc: 0.4932 - loss: 0.6913 - precision: 0.3826 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.4929 - val_loss: 0.6693 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 242ms/step - accuracy: 0.5851 - auc: 0.4939 - loss: 0.6841 - precision: 0.3824 - recall: 0.0719 - val_accuracy: 0.6082 - val_auc: 0.4963 - val_loss: 0.6775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 243ms/step - accuracy: 0.5864 - auc: 0.5037 - loss: 0.6798 - precision: 0.4192 - recall: 0.1062 - val_accuracy: 0.6082 - val_auc: 0.5301 - val_loss: 0.6706 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 249ms/step - accuracy: 0.6013 - auc: 0.4898 - loss: 0.6789 - precision: 0.4651 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.5792 - val_loss: 0.6698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 243ms/step - accuracy: 0.5969 - auc: 0.5126 - loss: 0.6771 - precision: 0.4198 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.5691 - val_loss: 0.6719 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 258ms/step - accuracy: 0.5899 - auc: 0.4934 - loss: 0.6792 - precision: 0.2698 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5869 - val_loss: 0.6722 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 240ms/step - accuracy: 0.6009 - auc: 0.4903 - loss: 0.6766 - precision: 0.3889 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5941 - val_loss: 0.6684 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 262ms/step - accuracy: 0.5982 - auc: 0.4956 - loss: 0.6768 - precision: 0.2727 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.5963 - val_loss: 0.6720 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 63s 241ms/step - accuracy: 0.6004 - auc: 0.5076 - loss: 0.6756 - precision: 0.4638 - recall: 0.0354 - val_accuracy: 0.6082 - val_auc: 0.5807 - val_loss: 0.6687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 250ms/step - accuracy: 0.5943 - auc: 0.5087 - loss: 0.6753 - precision: 0.2564 - recall: 0.0111 - val_accuracy: 0.6082 - val_auc: 0.6007 - val_loss: 0.6699 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 63s 242ms/step - accuracy: 0.5996 - auc: 0.4887 - loss: 0.6783 - precision: 0.3478 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.6085 - val_loss: 0.6683 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 252ms/step - accuracy: 0.5974 - auc: 0.5139 - loss: 0.6741 - precision: 0.3750 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.6136 - val_loss: 0.6782 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 257ms/step - accuracy: 0.6013 - auc: 0.5139 - loss: 0.6765 - precision: 0.4783 - recall: 0.0365 - val_accuracy: 0.6082 - val_auc: 0.6166 - val_loss: 0.6797 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 63s 240ms/step - accuracy: 0.5996 - auc: 0.5280 - loss: 0.6730 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6050 - val_loss: 0.6688 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 247ms/step - accuracy: 0.5974 - auc: 0.5234 - loss: 0.6735 - precision: 0.3800 - recall: 0.0210 - val_accuracy: 0.6082 - val_auc: 0.6022 - val_loss: 0.6828 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 250ms/step - accuracy: 0.5978 - auc: 0.4973 - loss: 0.6787 - precision: 0.4127 - recall: 0.0288 - val_accuracy: 0.6082 - val_auc: 0.6053 - val_loss: 0.6673 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 245ms/step - accuracy: 0.5666 - auc: 0.4785 - loss: 0.6882 - precision: 0.3536 - recall: 0.1095 - val_accuracy: 0.6082 - val_auc: 0.6119 - val_loss: 0.6680 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 247ms/step - accuracy: 0.6000 - auc: 0.5324 - loss: 0.6718 - precision: 0.3500 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6104 - val_loss: 0.6696 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 244ms/step - accuracy: 0.5991 - auc: 0.5158 - loss: 0.6744 - precision: 0.3889 - recall: 0.0155 - val_accuracy: 0.6082 - val_auc: 0.6129 - val_loss: 0.6671 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P7 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p7

# Prediction start time
predict_start_p7 = time.time()

# Resnet50 with p7 predictions
prediction_probs_p7 = resnet50_p7.predict(test_dataset_p7)

# Prediction end time
predict_end_p7 = time.time()

# Total prediction time for p7 in seconds
prediction_time_p7 = predict_end_p7 - predict_start_p7
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step

# %%
# Evaluation metrics for Resnet50 with p7
eval_metrics_p7 = resnet50_p7.evaluate(test_dataset_p7, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.5426 - auc: 0.6193 - loss: 0.6971 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p7 = np.where(prediction_probs_p7 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p7 true and predicted values
tn_p7, fp_p7, fn_p7, tp_p7 = confusion_matrix(true_pathology, predictions_p7).ravel()

# Compute specificity using CM
specificity_p7 = tn_p7 / (tn_p7 + fp_p7)

# Compute F1 Score using recall and precision
f1_score_p7 = 0.0
if eval_metrics_p7['precision'] + eval_metrics_p7['recall'] != 0.0:
  f1_score_p7 = (2 * eval_metrics_p7['precision'] * eval_metrics_p7['recall']) / (eval_metrics_p7['precision'] + eval_metrics_p7['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p7 = resnet50_p7.count_params()

# %%
# Generate a results dataframe for results of p7 experiment
results_p7 = generate_results_df('ResNet50', 'View_Independent', 'P7', eval_metrics_p7, specificity_p7, f1_score_p7, training_time_p7, prediction_time_p7, peak_memory_p7, resnet50_params_p7)

# Store p7 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p7)
# Out:
# Stored results for 0    P7
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P7 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P7 pipeline
plot_training_validation_loss(resnet50_p7.history, 'ResNet50 (View-Independent)', 'P7')

# %%
# Training-Validation Accuracy curve for P7 pipeline
plot_training_validation_accuracy(resnet50_p7.history, 'ResNet50 (View-Independent)', 'P7')

# %%
# Precision-Recall curve for P7 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p7, 'ResNet50 (View-Independent)', 'P7')

# %%
# Confusion matrix for P7 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p7, 'ResNet50 (View-Independent)', 'P7')

# %% [markdown]
# ## P8 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * CLAHE
# * Median Blur
# * Normalization

# %%
# Select the p8 image preprocessor function from the image preprocessor dictionary
p8 = IMAGE_PREPROCESSORS['P8']

# %%
# Create a tf.data dataset with p8 image preprocessing
train_dataset_p8 = generate_dataset(train_df, 32, p8, 'resnet50', training=True)
val_dataset_p8 = generate_dataset(val_df, 32, p8, 'resnet50', training=False)
test_dataset_p8 = generate_dataset(test_df, 32, p8, 'resnet50', training=False)

# %%
# Create a ResNet50 model for p8 pipeline
resnet50_p8 = create_resnet50_model()
resnet50_p8 = compile_model(resnet50_p8)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Train ResNet50 with training dataset for p8 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p8
train_start_p8 = time.time()

# ResNet50 with p8 training for 20 epochs
resnet50_p8.fit(train_dataset_p8, validation_data=val_dataset_p8, epochs=20)

# Memory used in p8
peak_memory_p8 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p8
train_end_p8 = time.time()

# Total training time for p8 in minutes
training_time_p8 = (train_end_p8 - train_start_p8)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 75s 253ms/step - accuracy: 0.5464 - auc: 0.5008 - loss: 0.7251 - precision: 0.3897 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5240 - val_loss: 0.6728 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 208ms/step - accuracy: 0.5705 - auc: 0.4938 - loss: 0.6912 - precision: 0.3834 - recall: 0.1327 - val_accuracy: 0.6082 - val_auc: 0.5198 - val_loss: 0.6691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 208ms/step - accuracy: 0.5859 - auc: 0.4951 - loss: 0.6839 - precision: 0.3895 - recall: 0.0741 - val_accuracy: 0.6082 - val_auc: 0.5312 - val_loss: 0.6774 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.5859 - auc: 0.5047 - loss: 0.6795 - precision: 0.4181 - recall: 0.1073 - val_accuracy: 0.6082 - val_auc: 0.5444 - val_loss: 0.6703 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 212ms/step - accuracy: 0.6009 - auc: 0.4936 - loss: 0.6783 - precision: 0.4545 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6123 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 217ms/step - accuracy: 0.5974 - auc: 0.5154 - loss: 0.6766 - precision: 0.4250 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.5870 - val_loss: 0.6713 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 228ms/step - accuracy: 0.5895 - auc: 0.4965 - loss: 0.6787 - precision: 0.2581 - recall: 0.0177 - val_accuracy: 0.6082 - val_auc: 0.6143 - val_loss: 0.6716 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 62s 217ms/step - accuracy: 0.6000 - auc: 0.4935 - loss: 0.6761 - precision: 0.3636 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.6108 - val_loss: 0.6677 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 208ms/step - accuracy: 0.5991 - auc: 0.5006 - loss: 0.6761 - precision: 0.3182 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6126 - val_loss: 0.6711 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 211ms/step - accuracy: 0.6013 - auc: 0.5121 - loss: 0.6749 - precision: 0.4800 - recall: 0.0398 - val_accuracy: 0.6082 - val_auc: 0.6294 - val_loss: 0.6678 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 211ms/step - accuracy: 0.5960 - auc: 0.5143 - loss: 0.6743 - precision: 0.3077 - recall: 0.0133 - val_accuracy: 0.6082 - val_auc: 0.6262 - val_loss: 0.6689 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 225ms/step - accuracy: 0.5991 - auc: 0.4962 - loss: 0.6771 - precision: 0.3462 - recall: 0.0100 - val_accuracy: 0.6082 - val_auc: 0.6264 - val_loss: 0.6671 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 223ms/step - accuracy: 0.5991 - auc: 0.5208 - loss: 0.6730 - precision: 0.4167 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6189 - val_loss: 0.6768 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 211ms/step - accuracy: 0.5996 - auc: 0.5178 - loss: 0.6756 - precision: 0.4507 - recall: 0.0354 - val_accuracy: 0.6082 - val_auc: 0.6267 - val_loss: 0.6785 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 209ms/step - accuracy: 0.6000 - auc: 0.5349 - loss: 0.6718 - precision: 0.3636 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.6440 - val_loss: 0.6673 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 213ms/step - accuracy: 0.5991 - auc: 0.5299 - loss: 0.6724 - precision: 0.4259 - recall: 0.0254 - val_accuracy: 0.6082 - val_auc: 0.6335 - val_loss: 0.6811 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.5982 - auc: 0.5053 - loss: 0.6772 - precision: 0.4265 - recall: 0.0321 - val_accuracy: 0.6082 - val_auc: 0.6455 - val_loss: 0.6657 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 213ms/step - accuracy: 0.5684 - auc: 0.4854 - loss: 0.6865 - precision: 0.3627 - recall: 0.1139 - val_accuracy: 0.6082 - val_auc: 0.6495 - val_loss: 0.6663 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 61s 220ms/step - accuracy: 0.6026 - auc: 0.5406 - loss: 0.6702 - precision: 0.5000 - recall: 0.0144 - val_accuracy: 0.6082 - val_auc: 0.6359 - val_loss: 0.6676 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 83s 214ms/step - accuracy: 0.6026 - auc: 0.5264 - loss: 0.6725 - precision: 0.5000 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.6468 - val_loss: 0.6652 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P8 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p8

# Prediction start time
predict_start_p8 = time.time()

# Resnet50 with p8 predictions
prediction_probs_p8 = resnet50_p8.predict(test_dataset_p8)

# Prediction end time
predict_end_p8 = time.time()

# Total prediction time for p8 in seconds
prediction_time_p8 = predict_end_p8 - predict_start_p8
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step

# %%
# Evaluation metrics for Resnet50 with p8
eval_metrics_p8 = resnet50_p8.evaluate(test_dataset_p8, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.5426 - auc: 0.6196 - loss: 0.6959 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p8 = np.where(prediction_probs_p8 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p8 true and predicted values
tn_p8, fp_p8, fn_p8, tp_p8 = confusion_matrix(true_pathology, predictions_p8).ravel()

# Compute specificity using CM
specificity_p8 = tn_p8 / (tn_p8 + fp_p8)

# Compute F1 Score using recall and precision
f1_score_p8 = 0.0
if eval_metrics_p8['precision'] + eval_metrics_p8['recall'] != 0.0:
  f1_score_p8 = (2 * eval_metrics_p8['precision'] * eval_metrics_p8['recall']) / (eval_metrics_p8['precision'] + eval_metrics_p8['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p8 = resnet50_p8.count_params()

# %%
# Generate a results dataframe for results of p8 experiment
results_p8 = generate_results_df('ResNet50', 'View_Independent', 'P8', eval_metrics_p8, specificity_p8, f1_score_p8, training_time_p8, prediction_time_p8, peak_memory_p8, resnet50_params_p8)

# Store p8 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p8)
# Out:
# Stored results for 0    P8
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P8 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P8 pipeline
plot_training_validation_loss(resnet50_p8.history, 'ResNet50 (View-Independent)', 'P8')

# %%
# Training-Validation Accuracy curve for P8 pipeline
plot_training_validation_accuracy(resnet50_p8.history, 'ResNet50 (View-Independent)', 'P8')

# %%
# Precision-Recall curve for P8 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p8, 'ResNet50 (View-Independent)', 'P8')

# %%
# Confusion matrix for P8 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p8, 'ResNet50 (View-Independent)', 'P8')

# %% [markdown]
# ## P9 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Gamma Correction
# * Median Blur
# * Normalization

# %%
# Select the p9 image preprocessor function from the image preprocessor dictionary
p9 = IMAGE_PREPROCESSORS['P9']

# %%
# Create a tf.data dataset with p9 image preprocessing
train_dataset_p9 = generate_dataset(train_df, 32, p9, 'resnet50', training=True)
val_dataset_p9 = generate_dataset(val_df, 32, p9, 'resnet50', training=False)
test_dataset_p9 = generate_dataset(test_df, 32, p9, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p9 pipeline
resnet50_p9 = create_resnet50_model()
resnet50_p9 = compile_model(resnet50_p9)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Train Resnet50 with training dataset for p9 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p9
train_start_p9 = time.time()

# Resnet50 with p9 training for 20 epochs
resnet50_p9.fit(train_dataset_p9, validation_data=val_dataset_p9, epochs=20)

# Memory used in p9
peak_memory_p9 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p9
train_end_p9 = time.time()

# Total training time for p9 in minutes
training_time_p9 = (train_end_p9 - train_start_p9)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 73s 242ms/step - accuracy: 0.5455 - auc: 0.5004 - loss: 0.7255 - precision: 0.3883 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5125 - val_loss: 0.6730 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.5714 - auc: 0.4927 - loss: 0.6915 - precision: 0.3851 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.5047 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 64s 278ms/step - accuracy: 0.5851 - auc: 0.4938 - loss: 0.6842 - precision: 0.3824 - recall: 0.0719 - val_accuracy: 0.6082 - val_auc: 0.5013 - val_loss: 0.6778 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 213ms/step - accuracy: 0.5864 - auc: 0.5029 - loss: 0.6800 - precision: 0.4199 - recall: 0.1073 - val_accuracy: 0.6082 - val_auc: 0.5001 - val_loss: 0.6707 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 213ms/step - accuracy: 0.6004 - auc: 0.4883 - loss: 0.6791 - precision: 0.4359 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5616 - val_loss: 0.6701 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 210ms/step - accuracy: 0.5969 - auc: 0.5109 - loss: 0.6774 - precision: 0.4217 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.5509 - val_loss: 0.6724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 210ms/step - accuracy: 0.5890 - auc: 0.4920 - loss: 0.6796 - precision: 0.2615 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5249 - val_loss: 0.6728 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.5996 - auc: 0.4867 - loss: 0.6771 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5374 - val_loss: 0.6690 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 211ms/step - accuracy: 0.5991 - auc: 0.4955 - loss: 0.6770 - precision: 0.3182 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5913 - val_loss: 0.6724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 214ms/step - accuracy: 0.6000 - auc: 0.5049 - loss: 0.6761 - precision: 0.4595 - recall: 0.0376 - val_accuracy: 0.6082 - val_auc: 0.5670 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 222ms/step - accuracy: 0.5938 - auc: 0.5023 - loss: 0.6761 - precision: 0.2222 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.5596 - val_loss: 0.6706 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 60s 227ms/step - accuracy: 0.5987 - auc: 0.4836 - loss: 0.6788 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5179 - val_loss: 0.6692 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 217ms/step - accuracy: 0.5974 - auc: 0.5065 - loss: 0.6752 - precision: 0.3636 - recall: 0.0177 - val_accuracy: 0.6082 - val_auc: 0.5280 - val_loss: 0.6787 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 211ms/step - accuracy: 0.5996 - auc: 0.5096 - loss: 0.6773 - precision: 0.4507 - recall: 0.0354 - val_accuracy: 0.6082 - val_auc: 0.5513 - val_loss: 0.6814 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.5996 - auc: 0.5225 - loss: 0.6740 - precision: 0.3158 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6175 - val_loss: 0.6700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 210ms/step - accuracy: 0.5974 - auc: 0.5177 - loss: 0.6745 - precision: 0.3750 - recall: 0.0199 - val_accuracy: 0.6082 - val_auc: 0.5603 - val_loss: 0.6836 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.5974 - auc: 0.4923 - loss: 0.6796 - precision: 0.3929 - recall: 0.0243 - val_accuracy: 0.6082 - val_auc: 0.5810 - val_loss: 0.6685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 59s 211ms/step - accuracy: 0.5666 - auc: 0.4752 - loss: 0.6888 - precision: 0.3525 - recall: 0.1084 - val_accuracy: 0.6082 - val_auc: 0.6229 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 58s 210ms/step - accuracy: 0.5987 - auc: 0.5260 - loss: 0.6731 - precision: 0.2000 - recall: 0.0033 - val_accuracy: 0.6082 - val_auc: 0.5969 - val_loss: 0.6707 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 57s 210ms/step - accuracy: 0.6004 - auc: 0.5083 - loss: 0.6755 - precision: 0.4286 - recall: 0.0166 - val_accuracy: 0.6082 - val_auc: 0.6195 - val_loss: 0.6684 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P9 Image Preprocessing Predictions

# %%
# Predict Resnet50's prediction probabilities using test data for p9

# Prediction start time
predict_start_p9 = time.time()

# Resnet50 with p9 predictions
prediction_probs_p9 = resnet50_p9.predict(test_dataset_p9)

# Prediction end time
predict_end_p9 = time.time()

# Total prediction time for p9 in seconds
prediction_time_p9 = predict_end_p9 - predict_start_p9
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step

# %%
# Evaluation metrics for Resnet50 with p9
eval_metrics_p9 = resnet50_p9.evaluate(test_dataset_p9, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5426 - auc: 0.6193 - loss: 0.6983 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p9 = np.where(prediction_probs_p9 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p9 true and predicted values
tn_p9, fp_p9, fn_p9, tp_p9 = confusion_matrix(true_pathology, predictions_p9).ravel()

# Compute specificity using CM
specificity_p9 = tn_p9 / (tn_p9 + fp_p9)

# Compute F1 Score using recall and precision
f1_score_p9 = 0.0
if eval_metrics_p9['precision'] + eval_metrics_p9['recall'] != 0.0:
  f1_score_p9 = (2 * eval_metrics_p9['precision'] * eval_metrics_p9['recall']) / (eval_metrics_p9['precision'] + eval_metrics_p9['recall'])

# Parameters of ResNet50 View-Independent model
resnet50_params_p9 = resnet50_p9.count_params()

# %%
# Generate a results dataframe for results of p9 experiment
results_p9 = generate_results_df('ResNet50', 'View_Independent', 'P9', eval_metrics_p9, specificity_p9, f1_score_p9, training_time_p9, prediction_time_p9, peak_memory_p9, resnet50_params_p9)

# Store p9 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p9)
# Out:
# Stored results for 0    P9
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P9 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P9 pipeline
plot_training_validation_loss(resnet50_p9.history, 'ResNet50 (View-Independent)', 'P9')

# %%
# Training-Validation Accuracy curve for P9 pipeline
plot_training_validation_accuracy(resnet50_p9.history, 'ResNet50 (View-Independent)', 'P9')

# %%
# Precision-Recall curve for P9 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p9, 'ResNet50 (View-Independent)', 'P9')

# %%
# Confusion matrix for P9 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p9, 'ResNet50 (View-Independent)', 'P9')

# %% [markdown]
# ## P10 Image Preprocessing Pipeline Experiment
#
# * Resizing
# * Grayscaling
# * CLAHE
# * Gamma Correction
# * Median Blur
# * Normalization

# %%
# Select the p10 image preprocessor function from the image preprocessor dictionary
p10 = IMAGE_PREPROCESSORS['P10']

# %%
# Create a tf.data dataset with p10 image preprocessing
train_dataset_p10 = generate_dataset(train_df, 32, p10, 'resnet50', training=True)
val_dataset_p10 = generate_dataset(val_df, 32, p10, 'resnet50', training=False)
test_dataset_p10 = generate_dataset(test_df, 32, p10, 'resnet50', training=False)

# %%
# Create a Resnet50 model for p10 pipeline
resnet50_p10 = create_resnet50_model()
resnet50_p10 = compile_model(resnet50_p10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Train ResNet50 with training dataset for p10 and compute its training time

# Reset memory for Peak GPU memory use computation
tf.config.experimental.reset_memory_stats('GPU:0')

# Training start time for p10
train_start_p10 = time.time()

# ResNet50 with p10 training for 20 epochs
resnet50_p10.fit(train_dataset_p10, validation_data=val_dataset_p10, epochs=20)

# Memory used in p10
peak_memory_p10 = tf.config.experimental.get_memory_info('GPU:0')['peak']

# Training end time for p10
train_end_p10 = time.time()

# Total training time for p10 in minutes
training_time_p10 = (train_end_p10 - train_start_p10)
# Out:
# Epoch 1/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 257ms/step - accuracy: 0.5459 - auc: 0.5004 - loss: 0.7254 - precision: 0.3890 - recall: 0.2500 - val_accuracy: 0.6082 - val_auc: 0.5151 - val_loss: 0.6730 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 219ms/step - accuracy: 0.5705 - auc: 0.4928 - loss: 0.6914 - precision: 0.3826 - recall: 0.1316 - val_accuracy: 0.6082 - val_auc: 0.4927 - val_loss: 0.6694 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 223ms/step - accuracy: 0.5846 - auc: 0.4938 - loss: 0.6842 - precision: 0.3801 - recall: 0.0719 - val_accuracy: 0.6082 - val_auc: 0.4991 - val_loss: 0.6777 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 68s 219ms/step - accuracy: 0.5864 - auc: 0.5032 - loss: 0.6799 - precision: 0.4192 - recall: 0.1062 - val_accuracy: 0.6082 - val_auc: 0.5141 - val_loss: 0.6707 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 226ms/step - accuracy: 0.6018 - auc: 0.4889 - loss: 0.6790 - precision: 0.4762 - recall: 0.0221 - val_accuracy: 0.6082 - val_auc: 0.5905 - val_loss: 0.6700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 220ms/step - accuracy: 0.5956 - auc: 0.5116 - loss: 0.6772 - precision: 0.4024 - recall: 0.0365 - val_accuracy: 0.6082 - val_auc: 0.5491 - val_loss: 0.6722 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 220ms/step - accuracy: 0.5899 - auc: 0.4932 - loss: 0.6794 - precision: 0.2698 - recall: 0.0188 - val_accuracy: 0.6082 - val_auc: 0.5622 - val_loss: 0.6725 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 227ms/step - accuracy: 0.5996 - auc: 0.4887 - loss: 0.6768 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5622 - val_loss: 0.6687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 221ms/step - accuracy: 0.5987 - auc: 0.4957 - loss: 0.6769 - precision: 0.3043 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.5990 - val_loss: 0.6722 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 71s 277ms/step - accuracy: 0.6004 - auc: 0.5060 - loss: 0.6758 - precision: 0.4648 - recall: 0.0365 - val_accuracy: 0.6082 - val_auc: 0.5924 - val_loss: 0.6690 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 227ms/step - accuracy: 0.5952 - auc: 0.5061 - loss: 0.6756 - precision: 0.2703 - recall: 0.0111 - val_accuracy: 0.6082 - val_auc: 0.5951 - val_loss: 0.6702 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 81s 219ms/step - accuracy: 0.5987 - auc: 0.4866 - loss: 0.6785 - precision: 0.3200 - recall: 0.0088 - val_accuracy: 0.6082 - val_auc: 0.5947 - val_loss: 0.6687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 69s 234ms/step - accuracy: 0.5974 - auc: 0.5095 - loss: 0.6745 - precision: 0.3636 - recall: 0.0177 - val_accuracy: 0.6082 - val_auc: 0.5976 - val_loss: 0.6784 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 66s 219ms/step - accuracy: 0.6018 - auc: 0.5127 - loss: 0.6769 - precision: 0.4861 - recall: 0.0387 - val_accuracy: 0.6082 - val_auc: 0.6122 - val_loss: 0.6805 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 82s 223ms/step - accuracy: 0.5996 - auc: 0.5246 - loss: 0.6734 - precision: 0.3333 - recall: 0.0077 - val_accuracy: 0.6082 - val_auc: 0.6081 - val_loss: 0.6693 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 84s 229ms/step - accuracy: 0.5978 - auc: 0.5209 - loss: 0.6739 - precision: 0.3878 - recall: 0.0210 - val_accuracy: 0.6082 - val_auc: 0.6085 - val_loss: 0.6830 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 72s 276ms/step - accuracy: 0.5987 - auc: 0.4949 - loss: 0.6790 - precision: 0.4237 - recall: 0.0277 - val_accuracy: 0.6082 - val_auc: 0.6084 - val_loss: 0.6678 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 68s 223ms/step - accuracy: 0.5688 - auc: 0.4775 - loss: 0.6884 - precision: 0.3600 - recall: 0.1095 - val_accuracy: 0.6082 - val_auc: 0.6197 - val_loss: 0.6686 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 67s 226ms/step - accuracy: 0.5996 - auc: 0.5310 - loss: 0.6722 - precision: 0.3158 - recall: 0.0066 - val_accuracy: 0.6082 - val_auc: 0.6186 - val_loss: 0.6700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 65s 219ms/step - accuracy: 0.5996 - auc: 0.5136 - loss: 0.6748 - precision: 0.4054 - recall: 0.0166 - val_accuracy: 0.6082 - val_auc: 0.6173 - val_loss: 0.6676 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### P10 Image Preprocessing Predictions

# %%
# Predict ResNet50's prediction probabilities using test data for p10

# Prediction start time
predict_start_p10 = time.time()

# ResNet50 with p10 predictions
prediction_probs_p10 = resnet50_p10.predict(test_dataset_p10)

# Prediction end time
predict_end_p10 = time.time()

# Total prediction time for p10 in seconds
prediction_time_p10 = predict_end_p10 - predict_start_p10
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step

# %%
# Evaluation metrics for ResNet50 with p10
eval_metrics_p10 = resnet50_p10.evaluate(test_dataset_p10, return_dict=True)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 138ms/step - accuracy: 0.5426 - auc: 0.6089 - loss: 0.6975 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
# Compute predictions using model's prediction probabilities
predictions_p10 = np.where(prediction_probs_p10 > 0.5, 1.0, 0.0)

# Generate confusion matrix for p10 true and predicted values
tn_p10, fp_p10, fn_p10, tp_p10 = confusion_matrix(true_pathology, predictions_p10).ravel()

# Compute specificity using CM
specificity_p10 = tn_p10 / (tn_p10 + fp_p10)

# Compute F1 Score using recall and precision
f1_score_p10 = 0.0
if eval_metrics_p10['precision'] + eval_metrics_p10['recall'] != 0.0:
  f1_score_p10 = (2 * eval_metrics_p10['precision'] * eval_metrics_p10['recall']) / (eval_metrics_p10['precision'] + eval_metrics_p10['recall'])

# Parameters of Resnet50 View-Independent model
resnet50_params_p10 = resnet50_p10.count_params()

# %%
# Generate a results dataframe for results of p10 experiment
results_p10 = generate_results_df('ResNet50', 'View_Independent', 'P10', eval_metrics_p10, specificity_p10, f1_score_p10, training_time_p10, prediction_time_p10, peak_memory_p10, resnet50_params_p10)

# Store p10 results into image preprocessing results csv
store_image_experiment_results(results_file_path, results_p10)
# Out:
# Stored results for 0    P10
# Name: image_preprocessing_pipeline, dtype: object pipeline

# %% [markdown]
# ### P10 Image Preprocessing Graphs

# %%
# Training-Validation Loss curve for P10 pipeline
plot_training_validation_loss(resnet50_p10.history, 'ResNet50 (View-Independent)', 'P10')

# %%
# Training-Validation Accuracy curve for P10 pipeline
plot_training_validation_accuracy(resnet50_p10.history, 'ResNet50 (View-Independent)', 'P10')

# %%
# Precision-Recall curve for P10 Pipeline
plot_precision_recall_curve(true_pathology_np, predictions_p10, 'ResNet50 (View-Independent)', 'P10')

# %%
# Confusion matrix for P10 pipeline
plot_confusion_matrix(true_pathology_np, predictions_p10, 'ResNet50 (View-Independent)', 'P10')
